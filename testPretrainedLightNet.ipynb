# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/heumchri/LightNet/blob/master/testPretrainedLightNet.ipynb)

# %%
import sys
sys.version
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
ls
# Out:
# datalab/

# %% [markdown]
# # Install CUDA

# %%
# !wget "https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64"
# Out:
# --2018-06-14 10:47:59--  https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.182.215
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.182.215|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/local_installers/cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64.deb?rB-7fotMj-ICoGvAx68xcNgaQc-v7BmXwvJZYAczbOnwuqgG_1c1L7ya_Twhv9dtcFQ5OGTv-LlDl7SYsd-1PZ9R15IaS18WkB4KZbkeRfxhekOgKAqO7Fpnmf5QJMVRkskA1orWWSHRgg-gvAskPjSp3C3V-kuXMiEd9eFMfVLcc0WPLZQH-SOT5_hLQ6PQDEtGewB_j6WTQbj_5qA [following]
# --2018-06-14 10:48:01--  https://developer.download.nvidia.com/compute/cuda/9.2/secure/Prod/local_installers/cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64.deb?rB-7fotMj-ICoGvAx68xcNgaQc-v7BmXwvJZYAczbOnwuqgG_1c1L7ya_Twhv9dtcFQ5OGTv-LlDl7SYsd-1PZ9R15IaS18WkB4KZbkeRfxhekOgKAqO7Fpnmf5QJMVRkskA1orWWSHRgg-gvAskPjSp3C3V-kuXMiEd9eFMfVLcc0WPLZQH-SOT5_hLQ6PQDEtGewB_j6WTQbj_5qA
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 192.229.221.58, 2606:2800:233:ef6:15dd:1ece:1d50:1e1
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|192.229.221.58|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1269204396 (1.2G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64’
#
# cuda-repo-ubuntu171 100%[===================>]   1.18G  67.6MB/s    in 12s
#
# 2018-06-14 10:48:14 (97.9 MB/s) - ‘cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64’ saved [1269204396/1269204396]

# %%
# !dpkg -i cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64
# Out:
# Selecting previously unselected package cuda-repo-ubuntu1710-9-2-local.
# (Reading database ... 18298 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1710-9-2-local_9.2.88-1_amd64 ...
# Unpacking cuda-repo-ubuntu1710-9-2-local (9.2.88-1) ...
# Setting up cuda-repo-ubuntu1710-9-2-local (9.2.88-1) ...
#
# The public CUDA GPG key does not appear to be installed.
# To install the key, run this command:
# sudo apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub

# %%
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# Out:
# OK

# %%
# !apt-get update
# Out:
# Get:1 file:/var/cuda-repo-9-2-local  InRelease
# Ign:1 file:/var/cuda-repo-9-2-local  InRelease
# Get:2 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:2 file:/var/cuda-repo-9-2-local  Release [574 B]
# Get:3 file:/var/cuda-repo-9-2-local  Release.gpg [801 B]
# Get:3 file:/var/cuda-repo-9-2-local  Release.gpg [801 B]
# Get:4 http://security.ubuntu.com/ubuntu artful-security InRelease [83.2 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu artful InRelease
# Get:6 http://archive.ubuntu.com/ubuntu artful-updates InRelease [88.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful-backports InRelease [74.6 kB]
# Get:8 file:/var/cuda-repo-9-2-local  Packages [18.7 kB]
# Get:9 http://security.ubuntu.com/ubuntu artful-security/universe Sources [21.0 kB]
# Get:10 http://security.ubuntu.com/ubuntu artful-security/restricted amd64 Packages [2,933 B]
# Get:11 http://security.ubuntu.com/ubuntu artful-security/universe amd64 Packages [83.8 kB]
# Get:12 http://security.ubuntu.com/ubuntu artful-security/multiverse amd64 Packages [1,815 B]
# Get:13 http://security.ubuntu.com/ubuntu artful-security/main amd64 Packages [234 kB]
# Get:14 http://archive.ubuntu.com/ubuntu artful-updates/universe Sources [44.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu artful-updates/restricted amd64 Packages [2,933 B]
# Get:16 http://archive.ubuntu.com/ubuntu artful-updates/universe amd64 Packages [148 kB]
# Get:17 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 Packages [361 kB]
# Get:18 http://archive.ubuntu.com/ubuntu artful-updates/multiverse amd64 Packages [4,369 B]
# Fetched 1,150 kB in 0s (1,187 kB/s)
# Reading package lists... Done

# %%
# !apt --fix-broken install
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.

# %%
# !apt-get install cuda
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   accountsservice acpid activity-log-manager adwaita-icon-theme apg aspell
#   aspell-en at-spi2-core avahi-daemon avahi-utils bbswitch-dkms bind9-host
#   bluez bluez-obexd bsdmainutils ca-certificates-java cheese-common
#   cracklib-runtime crda cuda-9-2 cuda-command-line-tools-9-2 cuda-compiler-9-2
#   cuda-cublas-9-2 cuda-cublas-dev-9-2 cuda-cudart-9-2 cuda-cudart-dev-9-2
#   cuda-cufft-9-2 cuda-cufft-dev-9-2 cuda-cuobjdump-9-2 cuda-cupti-9-2
#   cuda-curand-9-2 cuda-curand-dev-9-2 cuda-cusolver-9-2 cuda-cusolver-dev-9-2
#   cuda-cusparse-9-2 cuda-cusparse-dev-9-2 cuda-demo-suite-9-2
#   cuda-documentation-9-2 cuda-driver-dev-9-2 cuda-drivers cuda-gdb-9-2
#   cuda-gpu-library-advisor-9-2 cuda-libraries-9-2 cuda-libraries-dev-9-2
#   cuda-license-9-2 cuda-memcheck-9-2 cuda-misc-headers-9-2 cuda-npp-9-2
#   cuda-npp-dev-9-2 cuda-nsight-9-2 cuda-nvcc-9-2 cuda-nvdisasm-9-2
#   cuda-nvgraph-9-2 cuda-nvgraph-dev-9-2 cuda-nvml-dev-9-2 cuda-nvprof-9-2
#   cuda-nvprune-9-2 cuda-nvrtc-9-2 cuda-nvrtc-dev-9-2 cuda-nvtx-9-2
#   cuda-nvvp-9-2 cuda-runtime-9-2 cuda-samples-9-2 cuda-toolkit-9-2
#   cuda-tools-9-2 cuda-visual-tools-9-2 cups-pk-helper dbus dbus-user-session
#   dbus-x11 dconf-cli dconf-gsettings-backend dconf-service default-jre
#   default-jre-headless desktop-file-utils dictionaries-common distro-info-data
#   dkms dmsetup dns-root-data dnsmasq-base dosfstools eject emacsen-common
#   enchant evolution-data-server evolution-data-server-common fakeroot file
#   fontconfig fonts-dejavu-extra freeglut3 freeglut3-dev fuse gcr gdisk geoclue
#   geoclue-ubuntu-geoip geoip-database gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-glib-2.0 gir1.2-gtk-3.0
#   gir1.2-ibus-1.0 gir1.2-notify-0.7 gir1.2-packagekitglib-1.0 gir1.2-pango-1.0
#   gir1.2-polkit-1.0 gir1.2-secret-1 gkbd-capplet glib-networking
#   glib-networking-common glib-networking-services gnome-bluetooth
#   gnome-control-center-faces gnome-desktop3-data gnome-keyring gnome-menus
#   gnome-power-manager gnome-screensaver gnome-session-bin
#   gnome-settings-daemon-schemas groff-base gsettings-desktop-schemas
#   gsettings-ubuntu-schemas gstreamer1.0-clutter-3.0 gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x gtk-update-icon-cache gvfs
#   gvfs-backends gvfs-common gvfs-daemons gvfs-libs hicolor-icon-theme
#   humanity-icon-theme hunspell-en-us ibus ibus-gtk ibus-gtk3 im-config
#   indicator-applet indicator-application indicator-bluetooth indicator-common
#   indicator-datetime indicator-keyboard indicator-messages indicator-power
#   indicator-session indicator-sound ippusbxd iproute2 iptables iputils-arping
#   isc-dhcp-client isc-dhcp-common iso-codes iw java-common
#   keyboard-configuration kmod lib32gcc1 libaa1 libaccounts-glib0
#   libaccountsservice0 libapparmor1 libappindicator3-1 libappstream4
#   libarchive13 libasound2 libasound2-data libasound2-plugins libaspell15
#   libasyncns0 libatasmart4 libatk-bridge2.0-0 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data libatm1 libatspi2.0-0
#   libavahi-client3 libavahi-common-data libavahi-common3 libavahi-core7
#   libavahi-glib1 libavc1394-0 libbind9-140 libbluetooth3
#   libboost-filesystem1.62.0 libboost-system1.62.0 libboost-thread1.62.0
#   libc6-i386 libcaca0 libcairo-gobject2 libcairo2 libcamel-1.2-60
#   libcanberra-gtk3-0 libcanberra-gtk3-module libcanberra-pulse libcanberra0
#   libcap2 libcap2-bin libcapnp-0.5.3 libcdio-cdda1 libcdio-paranoia1 libcdio13
#   libcdparanoia0 libcheese-gtk25 libcheese8 libclutter-1.0-0
#   libclutter-1.0-common libclutter-gst-3.0-0 libclutter-gtk-1.0-0
#   libcogl-common libcogl-pango20 libcogl-path20 libcogl20 libcolord2 libcrack2
#   libcroco3 libcryptsetup4 libcuda1-396 libcups2 libdaemon0 libdatrie1
#   libdbus-1-3 libdbus-glib-1-2 libdbusmenu-glib4 libdbusmenu-gtk3-4 libdconf1
#   libdee-1.0-4 libdevmapper1.02.1 libdns-export162 libdns162 libdrm-amdgpu1
#   libdrm-common libdrm-dev libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libdrm2 libdv4 libebackend-1.2-10 libebook-1.2-19 libebook-contacts-1.2-2
#   libecal-1.2-19 libedata-book-1.2-25 libedata-cal-1.2-28
#   libedataserver-1.2-22 libegl1-mesa libelf1 libenchant1c2a libepoxy0
#   libevdev2 libexif12 libfakeroot libfcitx-config4 libfcitx-gclient0
#   libfcitx-utils0 libflac8 libfontenc1 libfribidi0 libfuse2 libgail-common
#   libgail18 libgbm1 libgck-1-0 libgcr-3-common libgcr-base-3-1 libgcr-ui-3-1
#   libgd3 libgdata-common libgdata22 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgee-0.8-2 libgeoclue0 libgeocode-glib0 libgeoip1
#   libgeonames-common libgeonames0 libgif7 libgirepository-1.0-1
#   libgl1-mesa-dev libgl1-mesa-dri libgl1-mesa-glx libglapi-mesa libgles2-mesa
#   libglib2.0-bin libglib2.0-data libglu1-mesa libglu1-mesa-dev
#   libgnome-bluetooth13 libgnome-desktop-3-12 libgnome-menu-3-0
#   libgnomekbd-common libgnomekbd8 libgoa-1.0-0b libgoa-1.0-common libgphoto2-6
#   libgphoto2-l10n libgphoto2-port12 libgpm2 libgraphite2-3
#   libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgstreamer1.0-0 libgtk-3-0 libgtk-3-bin libgtk-3-common libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libgtop-2.0-11 libgtop2-common libgudev-1.0-0
#   libgweather-3-6 libgweather-common libharfbuzz-icu0 libharfbuzz0b
#   libhunspell-1.6-0 libhyphen0 libibus-1.0-5 libical2 libice-dev libido3-0.1-0
#   libiec61883-0 libimobiledevice6 libindicator3-7 libinput-bin libinput10
#   libip4tc0 libip6tc0 libiptc0 libisc-export160 libisc160 libisccc140
#   libisccfg140 libjack-jackd2-0 libjansson4 libjavascriptcoregtk-4.0-18
#   libjbig0 libjson-c3 libjson-glib-1.0-0 libjson-glib-1.0-common libkmod2
#   liblcms2-2 libldb1 liblightdm-gobject-1-0 libllvm5.0 liblocale-gettext-perl
#   libltdl7 liblwres141 liblzo2-2 libmagic-mgc libmagic1 libmbim-glib4
#   libmbim-proxy libmessaging-menu0 libmirclient9 libmircommon7 libmircore1
#   libmirprotobuf3 libmm-glib0 libmnl0 libmtdev1 libmtp-common libmtp-runtime
#   libmtp9 libndp0 libnetfilter-conntrack3 libnewt0.52 libnfnetlink0
#   libnl-3-200 libnl-genl-3-200 libnm-glib4 libnm-gtk0 libnm-util2 libnm0
#   libnma0 libnotify4 libnspr4 libnss-mdns libnss3 libntfs-3g872 liboauth0
#   libogg0 libopus0 liborc-0.4-0 libp11-kit-gnome-keyring
#   libpackagekit-glib2-18 libpam-cap libpam-gnome-keyring libpam-systemd
#   libpanel-applet3 libpango-1.0-0 libpangocairo-1.0-0 libpangoft2-1.0-0
#   libpangoxft-1.0-0 libparted2 libpcap0.8 libpci3 libpciaccess0 libpcsclite1
#   libphonenumber7 libpipeline1 libpixman-1-0 libplist3 libplymouth4
#   libpolkit-agent-1-0 libpolkit-backend-1-0 libpolkit-gobject-1-0
#   libprotobuf-lite10 libprotobuf10 libproxy1v5 libpulse-mainloop-glib0
#   libpulse0 libpulsedsp libpwquality-common libpwquality1 libqmi-glib5
#   libqmi-proxy libraw1394-11 librest-0.7-0 librsvg2-2 librsvg2-common
#   libsamplerate0 libseccomp2 libsecret-1-0 libsecret-common libsensors4
#   libshout3 libslang2 libsm-dev libsmbclient libsndfile1 libsoup-gnome2.4-1
#   libsoup2.4-1 libspeex1 libspeexdsp1 libstemmer0d libsystemd0 libtag1v5
#   libtag1v5-vanilla libtalloc2 libtdb1 libtevent0 libtext-iconv-perl
#   libthai-data libthai0 libtheora0 libtiff5 libtimezonemap-data
#   libtimezonemap1 libtxc-dxtn-s2tc libudev1 libudisks2-0
#   libunity-control-center1 libunity-settings-daemon1 libupower-glib3
#   liburl-dispatcher1 libusb-1.0-0 libusbmuxd4 libv4l-0 libv4lconvert0
#   libvdpau1 libvisual-0.4-0 libvorbis0a libvorbisenc2 libvorbisfile3 libvpx4
#   libwacom-bin libwacom-common libwacom2 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1-mesa libwayland-server0 libwbclient0
#   libwebkit2gtk-4.0-37 libwebp6 libwebpdemux2 libwebrtc-audio-processing1
#   libwhoopsie-preferences0 libwhoopsie0 libwrap0 libx11-xcb-dev libx11-xcb1
#   libxapian30 libxatracker2 libxaw7 libxcb-dri2-0 libxcb-dri2-0-dev
#   libxcb-dri3-0 libxcb-dri3-dev libxcb-glx0 libxcb-glx0-dev libxcb-present-dev
#   libxcb-present0 libxcb-randr0 libxcb-randr0-dev libxcb-render0
#   libxcb-render0-dev libxcb-shape0 libxcb-shape0-dev libxcb-shm0
#   libxcb-sync-dev libxcb-sync1 libxcb-util1 libxcb-xfixes0 libxcb-xfixes0-dev
#   libxcomposite1 libxcursor1 libxdamage-dev libxdamage1 libxext-dev
#   libxfixes-dev libxfixes3 libxfont1 libxfont2 libxi-dev libxi6 libxinerama1
#   libxkbcommon0 libxkbfile1 libxklavier16 libxmu-dev libxmu-headers libxmu6
#   libxmuu1 libxnvctrl0 libxpm4 libxrandr2 libxshmfence-dev libxshmfence1
#   libxslt1.1 libxt-dev libxt6 libxtables12 libxtst6 libxv1 libxvmc1
#   libxxf86dga1 libxxf86vm-dev libxxf86vm1 libyaml-0-2 libyelp0
#   libzeitgeist-2.0-0 lightdm linux-headers-4.13.0-45
#   linux-headers-4.13.0-45-generic linux-headers-generic lsb-release man-db
#   mesa-common-dev mesa-vdpau-drivers mobile-broadband-provider-info
#   modemmanager mousetweaks nautilus-data network-manager network-manager-gnome
#   network-manager-pptp notification-daemon ntfs-3g nvidia-396 nvidia-396-dev
#   nvidia-modprobe nvidia-opencl-icd-396 nvidia-prime nvidia-settings
#   ocl-icd-libopencl1 openjdk-8-jre openjdk-8-jre-headless p11-kit
#   p11-kit-modules packagekit packagekit-tools parted pciutils pinentry-gnome3
#   plymouth plymouth-theme-ubuntu-text policykit-1 policykit-1-gnome ppp
#   pptp-linux psmisc pulseaudio pulseaudio-utils python-apt-common
#   python-talloc python3-apt python3-cairo python3-certifi python3-chardet
#   python3-cups python3-cupshelpers python3-dbus python3-gi python3-idna
#   python3-pkg-resources python3-requests python3-six python3-urllib3
#   python3-xdg python3-xkit rtkit samba-libs screen-resolution-extra
#   shared-mime-info sound-theme-freedesktop sudo system-config-printer
#   system-config-printer-common system-config-printer-udev systemd systemd-sysv
#   tcpd ubuntu-mono ubuntu-system-service ubuntu-touch-sounds udev udisks2
#   unity-control-center unity-greeter unity-settings-daemon upower
#   usb-modeswitch usb-modeswitch-data usbmuxd vdpau-driver-all wamerican
#   whoopsie-preferences wireless-regdb wpasupplicant x11-utils x11-xkb-utils
#   x11proto-damage-dev x11proto-dri2-dev x11proto-fixes-dev x11proto-gl-dev
#   x11proto-xext-dev x11proto-xf86vidmode-dev xauth xfonts-base
#   xfonts-encodings xfonts-utils xkb-data xserver-common xserver-xorg
#   xserver-xorg-core xserver-xorg-input-all xserver-xorg-input-libinput
#   xserver-xorg-input-wacom xserver-xorg-legacy xserver-xorg-video-all
#   xserver-xorg-video-amdgpu xserver-xorg-video-ati xserver-xorg-video-fbdev
#   xserver-xorg-video-intel xserver-xorg-video-nouveau xserver-xorg-video-qxl
#   xserver-xorg-video-radeon xserver-xorg-video-vesa xserver-xorg-video-vmware
#   yelp yelp-xsl zeitgeist-core zenity zenity-common
# Suggested packages:
#   gnome-control-center aspell-doc spellutils avahi-autoipd bumblebee whois
#   vacation default-java-plugin python3-apport menu cdtool setcd evolution
#   groff samba-common hunspell openoffice.org-hunspell | openoffice.org-core
#   ibus-clutter ibus-doc ibus-qt4 libqt5gui5 apport
#   unity-greeter-session-broadcast iproute2-doc resolvconf isc-dhcp-client-ddns
#   isoquery lrzip alsa-utils libcanberra-gtk0 colord cups-common libdv-bin
#   oss-compat libenchant-voikko fcitx libgd-tools geoip-bin gphoto2 gpm
#   libvisual-0.4-plugins gstreamer1.0-tools libice-doc libusbmuxd-tools jackd2
#   liblcms2-utils avahi-autoipd | zeroconf opus-tools libparted-dev
#   libparted-i18n pcscd libraw1394-doc librsvg2-bin lm-sensors libsm-doc speex
#   url-dispatcher libwebkit2gtk-4.0-37-gtk2 xapian-tools libxext-doc libxt-doc
#   bindfs lsb less www-browser nautilus network-manager-openconnect-gnome
#   network-manager-openvpn-gnome network-manager-vpnc-gnome
#   network-manager-pptp-gnome icedtea-8-plugin fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei fonts-wqy-zenhei fonts-indic
#   appstream parted-doc pinentry-doc desktop-base plymouth-themes pavumeter
#   pavucontrol paman paprefs ubuntu-sounds python3-apt-dbg python-apt-doc
#   python-dbus-doc python3-dbus-dbg python3-setuptools python3-cryptography
#   python3-openssl python3-socks gnome-software python3-smbc systemd-container
#   btrfs-progs | btrfs-tools cryptsetup-bin exfat-utils mdadm reiserfsprogs
#   xfsprogs gnome-user-guide | ubuntu-docs libcanberra-gtk-module
#   x11-xserver-utils lightdm-remote-session-freerdp
#   lightdm-remote-session-uccsconfigure remote-login-service metacity
#   | x-window-manager comgt wvdial libvdpau-va-gl1 nvidia-vdpau-driver
#   nvidia-legacy-340xx-vdpau-driver wpagui libengine-pkcs11-openssl mesa-utils
#   xfonts-100dpi | xfonts-75dpi xfonts-scalable xinput firmware-amd-graphics
#   xserver-xorg-video-r128 xserver-xorg-video-mach64 firmware-misc-nonfree
#   zeitgeist-datahub
# Recommended packages:
#   systemd-services
# The following NEW packages will be installed:
#   accountsservice acpid activity-log-manager adwaita-icon-theme apg aspell
#   aspell-en at-spi2-core avahi-daemon avahi-utils bbswitch-dkms bind9-host
#   bluez bluez-obexd bsdmainutils ca-certificates-java cheese-common
#   cracklib-runtime crda cuda cuda-9-2 cuda-command-line-tools-9-2
#   cuda-compiler-9-2 cuda-cublas-9-2 cuda-cublas-dev-9-2 cuda-cudart-9-2
#   cuda-cudart-dev-9-2 cuda-cufft-9-2 cuda-cufft-dev-9-2 cuda-cuobjdump-9-2
#   cuda-cupti-9-2 cuda-curand-9-2 cuda-curand-dev-9-2 cuda-cusolver-9-2
#   cuda-cusolver-dev-9-2 cuda-cusparse-9-2 cuda-cusparse-dev-9-2
#   cuda-demo-suite-9-2 cuda-documentation-9-2 cuda-driver-dev-9-2 cuda-drivers
#   cuda-gdb-9-2 cuda-gpu-library-advisor-9-2 cuda-libraries-9-2
#   cuda-libraries-dev-9-2 cuda-license-9-2 cuda-memcheck-9-2
#   cuda-misc-headers-9-2 cuda-npp-9-2 cuda-npp-dev-9-2 cuda-nsight-9-2
#   cuda-nvcc-9-2 cuda-nvdisasm-9-2 cuda-nvgraph-9-2 cuda-nvgraph-dev-9-2
#   cuda-nvml-dev-9-2 cuda-nvprof-9-2 cuda-nvprune-9-2 cuda-nvrtc-9-2
#   cuda-nvrtc-dev-9-2 cuda-nvtx-9-2 cuda-nvvp-9-2 cuda-runtime-9-2
#   cuda-samples-9-2 cuda-toolkit-9-2 cuda-tools-9-2 cuda-visual-tools-9-2
#   cups-pk-helper dbus dbus-user-session dbus-x11 dconf-cli
#   dconf-gsettings-backend dconf-service default-jre default-jre-headless
#   desktop-file-utils dictionaries-common distro-info-data dkms dmsetup
#   dns-root-data dnsmasq-base dosfstools eject emacsen-common enchant
#   evolution-data-server evolution-data-server-common fakeroot file fontconfig
#   fonts-dejavu-extra freeglut3 freeglut3-dev fuse gcr gdisk geoclue
#   geoclue-ubuntu-geoip geoip-database gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-glib-2.0 gir1.2-gtk-3.0
#   gir1.2-ibus-1.0 gir1.2-notify-0.7 gir1.2-packagekitglib-1.0 gir1.2-pango-1.0
#   gir1.2-polkit-1.0 gir1.2-secret-1 gkbd-capplet glib-networking
#   glib-networking-common glib-networking-services gnome-bluetooth
#   gnome-control-center-faces gnome-desktop3-data gnome-keyring gnome-menus
#   gnome-power-manager gnome-screensaver gnome-session-bin
#   gnome-settings-daemon-schemas groff-base gsettings-desktop-schemas
#   gsettings-ubuntu-schemas gstreamer1.0-clutter-3.0 gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x gtk-update-icon-cache gvfs
#   gvfs-backends gvfs-common gvfs-daemons gvfs-libs hicolor-icon-theme
#   humanity-icon-theme hunspell-en-us ibus ibus-gtk ibus-gtk3 im-config
#   indicator-applet indicator-application indicator-bluetooth indicator-common
#   indicator-datetime indicator-keyboard indicator-messages indicator-power
#   indicator-session indicator-sound ippusbxd iproute2 iptables iputils-arping
#   isc-dhcp-client isc-dhcp-common iso-codes iw java-common
#   keyboard-configuration kmod lib32gcc1 libaa1 libaccounts-glib0
#   libaccountsservice0 libapparmor1 libappindicator3-1 libappstream4
#   libarchive13 libasound2 libasound2-data libasound2-plugins libaspell15
#   libasyncns0 libatasmart4 libatk-bridge2.0-0 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0 libatk1.0-data libatm1 libatspi2.0-0
#   libavahi-client3 libavahi-common-data libavahi-common3 libavahi-core7
#   libavahi-glib1 libavc1394-0 libbind9-140 libbluetooth3
#   libboost-filesystem1.62.0 libboost-system1.62.0 libboost-thread1.62.0
#   libc6-i386 libcaca0 libcairo-gobject2 libcairo2 libcamel-1.2-60
#   libcanberra-gtk3-0 libcanberra-gtk3-module libcanberra-pulse libcanberra0
#   libcap2 libcap2-bin libcapnp-0.5.3 libcdio-cdda1 libcdio-paranoia1 libcdio13
#   libcdparanoia0 libcheese-gtk25 libcheese8 libclutter-1.0-0
#   libclutter-1.0-common libclutter-gst-3.0-0 libclutter-gtk-1.0-0
#   libcogl-common libcogl-pango20 libcogl-path20 libcogl20 libcolord2 libcrack2
#   libcroco3 libcryptsetup4 libcuda1-396 libcups2 libdaemon0 libdatrie1
#   libdbus-1-3 libdbus-glib-1-2 libdbusmenu-glib4 libdbusmenu-gtk3-4 libdconf1
#   libdee-1.0-4 libdevmapper1.02.1 libdns-export162 libdns162 libdrm-amdgpu1
#   libdrm-common libdrm-dev libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libdrm2 libdv4 libebackend-1.2-10 libebook-1.2-19 libebook-contacts-1.2-2
#   libecal-1.2-19 libedata-book-1.2-25 libedata-cal-1.2-28
#   libedataserver-1.2-22 libegl1-mesa libelf1 libenchant1c2a libepoxy0
#   libevdev2 libexif12 libfakeroot libfcitx-config4 libfcitx-gclient0
#   libfcitx-utils0 libflac8 libfontenc1 libfribidi0 libfuse2 libgail-common
#   libgail18 libgbm1 libgck-1-0 libgcr-3-common libgcr-base-3-1 libgcr-ui-3-1
#   libgd3 libgdata-common libgdata22 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgee-0.8-2 libgeoclue0 libgeocode-glib0 libgeoip1
#   libgeonames-common libgeonames0 libgif7 libgirepository-1.0-1
#   libgl1-mesa-dev libgl1-mesa-dri libgl1-mesa-glx libglapi-mesa libgles2-mesa
#   libglib2.0-bin libglib2.0-data libglu1-mesa libglu1-mesa-dev
#   libgnome-bluetooth13 libgnome-desktop-3-12 libgnome-menu-3-0
#   libgnomekbd-common libgnomekbd8 libgoa-1.0-0b libgoa-1.0-common libgphoto2-6
#   libgphoto2-l10n libgphoto2-port12 libgpm2 libgraphite2-3
#   libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgstreamer1.0-0 libgtk-3-0 libgtk-3-bin libgtk-3-common libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libgtop-2.0-11 libgtop2-common libgudev-1.0-0
#   libgweather-3-6 libgweather-common libharfbuzz-icu0 libharfbuzz0b
#   libhunspell-1.6-0 libhyphen0 libibus-1.0-5 libical2 libice-dev libido3-0.1-0
#   libiec61883-0 libimobiledevice6 libindicator3-7 libinput-bin libinput10
#   libip4tc0 libip6tc0 libiptc0 libisc-export160 libisc160 libisccc140
#   libisccfg140 libjack-jackd2-0 libjansson4 libjavascriptcoregtk-4.0-18
#   libjbig0 libjson-c3 libjson-glib-1.0-0 libjson-glib-1.0-common libkmod2
#   liblcms2-2 libldb1 liblightdm-gobject-1-0 libllvm5.0 liblocale-gettext-perl
#   libltdl7 liblwres141 liblzo2-2 libmagic-mgc libmagic1 libmbim-glib4
#   libmbim-proxy libmessaging-menu0 libmirclient9 libmircommon7 libmircore1
#   libmirprotobuf3 libmm-glib0 libmnl0 libmtdev1 libmtp-common libmtp-runtime
#   libmtp9 libndp0 libnetfilter-conntrack3 libnewt0.52 libnfnetlink0
#   libnl-3-200 libnl-genl-3-200 libnm-glib4 libnm-gtk0 libnm-util2 libnm0
#   libnma0 libnotify4 libnspr4 libnss-mdns libnss3 libntfs-3g872 liboauth0
#   libogg0 libopus0 liborc-0.4-0 libp11-kit-gnome-keyring
#   libpackagekit-glib2-18 libpam-cap libpam-gnome-keyring libpam-systemd
#   libpanel-applet3 libpango-1.0-0 libpangocairo-1.0-0 libpangoft2-1.0-0
#   libpangoxft-1.0-0 libparted2 libpcap0.8 libpci3 libpciaccess0 libpcsclite1
#   libphonenumber7 libpipeline1 libpixman-1-0 libplist3 libplymouth4
#   libpolkit-agent-1-0 libpolkit-backend-1-0 libpolkit-gobject-1-0
#   libprotobuf-lite10 libprotobuf10 libproxy1v5 libpulse-mainloop-glib0
#   libpulse0 libpulsedsp libpwquality-common libpwquality1 libqmi-glib5
#   libqmi-proxy libraw1394-11 librest-0.7-0 librsvg2-2 librsvg2-common
#   libsamplerate0 libseccomp2 libsecret-1-0 libsecret-common libsensors4
#   libshout3 libslang2 libsm-dev libsmbclient libsndfile1 libsoup-gnome2.4-1
#   libsoup2.4-1 libspeex1 libspeexdsp1 libstemmer0d libtag1v5 libtag1v5-vanilla
#   libtalloc2 libtdb1 libtevent0 libtext-iconv-perl libthai-data libthai0
#   libtheora0 libtiff5 libtimezonemap-data libtimezonemap1 libtxc-dxtn-s2tc
#   libudisks2-0 libunity-control-center1 libunity-settings-daemon1
#   libupower-glib3 liburl-dispatcher1 libusb-1.0-0 libusbmuxd4 libv4l-0
#   libv4lconvert0 libvdpau1 libvisual-0.4-0 libvorbis0a libvorbisenc2
#   libvorbisfile3 libvpx4 libwacom-bin libwacom-common libwacom2 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1-mesa
#   libwayland-server0 libwbclient0 libwebkit2gtk-4.0-37 libwebp6 libwebpdemux2
#   libwebrtc-audio-processing1 libwhoopsie-preferences0 libwhoopsie0 libwrap0
#   libx11-xcb-dev libx11-xcb1 libxapian30 libxatracker2 libxaw7 libxcb-dri2-0
#   libxcb-dri2-0-dev libxcb-dri3-0 libxcb-dri3-dev libxcb-glx0 libxcb-glx0-dev
#   libxcb-present-dev libxcb-present0 libxcb-randr0 libxcb-randr0-dev
#   libxcb-render0 libxcb-render0-dev libxcb-shape0 libxcb-shape0-dev
#   libxcb-shm0 libxcb-sync-dev libxcb-sync1 libxcb-util1 libxcb-xfixes0
#   libxcb-xfixes0-dev libxcomposite1 libxcursor1 libxdamage-dev libxdamage1
#   libxext-dev libxfixes-dev libxfixes3 libxfont1 libxfont2 libxi-dev libxi6
#   libxinerama1 libxkbcommon0 libxkbfile1 libxklavier16 libxmu-dev
#   libxmu-headers libxmu6 libxmuu1 libxnvctrl0 libxpm4 libxrandr2
#   libxshmfence-dev libxshmfence1 libxslt1.1 libxt-dev libxt6 libxtables12
#   libxtst6 libxv1 libxvmc1 libxxf86dga1 libxxf86vm-dev libxxf86vm1 libyaml-0-2
#   libyelp0 libzeitgeist-2.0-0 lightdm linux-headers-4.13.0-45
#   linux-headers-4.13.0-45-generic linux-headers-generic lsb-release man-db
#   mesa-common-dev mesa-vdpau-drivers mobile-broadband-provider-info
#   modemmanager mousetweaks nautilus-data network-manager network-manager-gnome
#   network-manager-pptp notification-daemon ntfs-3g nvidia-396 nvidia-396-dev
#   nvidia-modprobe nvidia-opencl-icd-396 nvidia-prime nvidia-settings
#   ocl-icd-libopencl1 openjdk-8-jre openjdk-8-jre-headless p11-kit
#   p11-kit-modules packagekit packagekit-tools parted pciutils pinentry-gnome3
#   plymouth plymouth-theme-ubuntu-text policykit-1 policykit-1-gnome ppp
#   pptp-linux psmisc pulseaudio pulseaudio-utils python-apt-common
#   python-talloc python3-apt python3-cairo python3-certifi python3-chardet
#   python3-cups python3-cupshelpers python3-dbus python3-gi python3-idna
#   python3-pkg-resources python3-requests python3-six python3-urllib3
#   python3-xdg python3-xkit rtkit samba-libs screen-resolution-extra
#   shared-mime-info sound-theme-freedesktop sudo system-config-printer
#   system-config-printer-common system-config-printer-udev systemd systemd-sysv
#   tcpd ubuntu-mono ubuntu-system-service ubuntu-touch-sounds udev udisks2
#   unity-control-center unity-greeter unity-settings-daemon upower
#   usb-modeswitch usb-modeswitch-data usbmuxd vdpau-driver-all wamerican
#   whoopsie-preferences wireless-regdb wpasupplicant x11-utils x11-xkb-utils
#   x11proto-damage-dev x11proto-dri2-dev x11proto-fixes-dev x11proto-gl-dev
#   x11proto-xext-dev x11proto-xf86vidmode-dev xauth xfonts-base
#   xfonts-encodings xfonts-utils xkb-data xserver-common xserver-xorg
#   xserver-xorg-core xserver-xorg-input-all xserver-xorg-input-libinput
#   xserver-xorg-input-wacom xserver-xorg-legacy xserver-xorg-video-all
#   xserver-xorg-video-amdgpu xserver-xorg-video-ati xserver-xorg-video-fbdev
#   xserver-xorg-video-intel xserver-xorg-video-nouveau xserver-xorg-video-qxl
#   xserver-xorg-video-radeon xserver-xorg-video-vesa xserver-xorg-video-vmware
#   yelp yelp-xsl zeitgeist-core zenity zenity-common
# The following packages will be upgraded:
#   libsystemd0 libudev1
# 2 upgraded, 679 newly installed, 0 to remove and 21 not upgraded.
# Need to get 192 MB/1,426 MB of archives.
# After this operation, 3,939 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-9-2-local  cuda-license-9-2 9.2.88-1 [22.0 kB]
# Get:2 file:/var/cuda-repo-9-2-local  cuda-misc-headers-9-2 9.2.88-1 [640 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libsystemd0 amd64 234-2ubuntu12.4 [209 kB]
# 0% [3 libsystemd0 0 B/209 kB 0%]
# Get:4 http://archive.ubuntu.com/ubuntu artful/main amd64 liblocale-gettext-perl amd64 1.07-3build2 [16.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu artful/main amd64 keyboard-configuration all 1.166ubuntu7 [622 kB]
# Get:6 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libapparmor1 amd64 2.11.0-2ubuntu17.1 [28.9 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful/main amd64 libcap2 amd64 1:2.25-1.1 [13.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libudev1 amd64 234-2ubuntu12.4 [52.4 kB]
# Get:9 http://archive.ubuntu.com/ubuntu artful/main amd64 libdevmapper1.02.1 amd64 2:1.02.137-2ubuntu3 [135 kB]
# Get:10 http://archive.ubuntu.com/ubuntu artful/main amd64 libcryptsetup4 amd64 2:1.7.3-4ubuntu1 [77.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu artful/main amd64 libip4tc0 amd64 1.6.1-2ubuntu1 [19.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu artful/main amd64 libkmod2 amd64 24-1ubuntu2 [40.1 kB]
# Get:13 http://archive.ubuntu.com/ubuntu artful/main amd64 libseccomp2 amd64 2.3.1-2.1ubuntu3 [37.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 systemd amd64 234-2ubuntu12.4 [2,782 kB]
# Get:15 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 systemd-sysv amd64 234-2ubuntu12.4 [11.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 udev amd64 234-2ubuntu12.4 [1,092 kB]
# Get:17 http://archive.ubuntu.com/ubuntu artful/main amd64 libnfnetlink0 amd64 1.0.1-3 [13.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu artful/main amd64 groff-base amd64 1.22.3-9 [1,144 kB]
# Get:19 http://archive.ubuntu.com/ubuntu artful/main amd64 bsdmainutils amd64 9.0.12+nmu1ubuntu1 [179 kB]
# Get:20 http://archive.ubuntu.com/ubuntu artful/main amd64 libpipeline1 amd64 1.4.2-1 [25.2 kB]
# Get:21 http://archive.ubuntu.com/ubuntu artful/main amd64 man-db amd64 2.7.6.1-2 [895 kB]
# Get:22 http://archive.ubuntu.com/ubuntu artful/main amd64 libfuse2 amd64 2.9.7-1ubuntu1 [80.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu artful/main amd64 fuse amd64 2.9.7-1ubuntu1 [24.5 kB]
# Get:24 http://archive.ubuntu.com/ubuntu artful/main amd64 libntfs-3g872 amd64 1:2016.2.22AR.2-2 [145 kB]
# Get:25 http://archive.ubuntu.com/ubuntu artful/main amd64 ntfs-3g amd64 1:2016.2.22AR.2-2 [380 kB]
# Get:26 http://archive.ubuntu.com/ubuntu artful/main amd64 fontconfig amd64 2.11.94-0ubuntu2 [177 kB]
# Get:27 http://archive.ubuntu.com/ubuntu artful/main amd64 libdbusmenu-glib4 amd64 16.04.1+17.04.20170109.1-0ubuntu1 [40.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu artful/main amd64 libatk1.0-data all 2.26.0-2ubuntu1 [2,820 B]
# Get:29 http://archive.ubuntu.com/ubuntu artful/main amd64 libatk1.0-0 amd64 2.26.0-2ubuntu1 [44.2 kB]
# Get:30 http://archive.ubuntu.com/ubuntu artful/main amd64 libjbig0 amd64 2.1-3.1 [26.6 kB]
# Get:31 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libtiff5 amd64 4.0.8-5ubuntu0.1 [150 kB]
# Get:32 http://archive.ubuntu.com/ubuntu artful/main amd64 shared-mime-info amd64 1.8-1 [420 kB]
# Get:33 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgdk-pixbuf2.0-common all 2.36.11-1ubuntu0.1 [4,488 B]
# Get:34 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgdk-pixbuf2.0-0 amd64 2.36.11-1ubuntu0.1 [165 kB]
# Get:35 http://archive.ubuntu.com/ubuntu artful/main amd64 libthai-data all 0.1.26-3 [132 kB]
# Get:36 http://archive.ubuntu.com/ubuntu artful/main amd64 libdatrie1 amd64 0.2.10-5 [17.6 kB]
# Get:37 http://archive.ubuntu.com/ubuntu artful/main amd64 libthai0 amd64 0.1.26-3 [17.7 kB]
# Get:38 http://archive.ubuntu.com/ubuntu artful/main amd64 libpango-1.0-0 amd64 1.40.12-1 [152 kB]
# Get:39 http://archive.ubuntu.com/ubuntu artful/main amd64 libdbusmenu-gtk3-4 amd64 16.04.1+17.04.20170109.1-0ubuntu1 [26.7 kB]
# Get:40 http://archive.ubuntu.com/ubuntu artful/main amd64 libdconf1 amd64 0.26.0-2 [33.0 kB]
# Get:41 http://archive.ubuntu.com/ubuntu artful/main amd64 dconf-service amd64 0.26.0-2 [27.2 kB]
# Get:42 http://archive.ubuntu.com/ubuntu artful/main amd64 dconf-gsettings-backend amd64 0.26.0-2 [20.0 kB]
# Get:43 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgtk-3-common all 3.22.25-0ubuntu0.1 [226 kB]
# Get:44 http://archive.ubuntu.com/ubuntu artful/main amd64 libdbus-1-3 amd64 1.10.22-1ubuntu1 [165 kB]
# Get:45 http://archive.ubuntu.com/ubuntu artful/main amd64 libatspi2.0-0 amd64 2.26.0-2 [60.1 kB]
# Get:46 http://archive.ubuntu.com/ubuntu artful/main amd64 libatk-bridge2.0-0 amd64 2.26.0-1ubuntu1 [54.2 kB]
# Get:47 http://archive.ubuntu.com/ubuntu artful/main amd64 libpixman-1-0 amd64 0.34.0-1 [230 kB]
# Get:48 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-render0 amd64 1.12-1ubuntu1 [14.8 kB]
# Get:49 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-shm0 amd64 1.12-1ubuntu1 [5,482 B]
# Get:50 http://archive.ubuntu.com/ubuntu artful/main amd64 libcairo2 amd64 1.14.10-1ubuntu1 [558 kB]
# Get:51 file:/var/cuda-repo-9-2-local  cuda-nvcc-9-2 9.2.88-1 [15.4 MB]
# Get:52 http://archive.ubuntu.com/ubuntu artful/main amd64 libcairo-gobject2 amd64 1.14.10-1ubuntu1 [17.1 kB]
# Get:53 http://archive.ubuntu.com/ubuntu artful/main amd64 liblcms2-2 amd64 2.7-1ubuntu1 [137 kB]
# Get:54 file:/var/cuda-repo-9-2-local  cuda-cuobjdump-9-2 9.2.88-1 [129 kB]
# Get:55 file:/var/cuda-repo-9-2-local  cuda-nvprune-9-2 9.2.88-1 [36.7 kB]
# Get:56 http://archive.ubuntu.com/ubuntu artful/main amd64 libcolord2 amd64 1.3.3-2build1 [107 kB]
# Get:57 file:/var/cuda-repo-9-2-local  cuda-compiler-9-2 9.2.88-1 [2,518 B]
# Get:58 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libavahi-common-data amd64 0.6.32-1ubuntu1.1 [22.0 kB]
# Get:59 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libavahi-common3 amd64 0.6.32-1ubuntu1.1 [21.6 kB]
# Get:60 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libavahi-client3 amd64 0.6.32-1ubuntu1.1 [25.2 kB]
# Get:61 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libcups2 amd64 2.2.4-7ubuntu3 [209 kB]
# Get:62 http://archive.ubuntu.com/ubuntu artful/main amd64 libepoxy0 amd64 1.3.1-3 [176 kB]
# Get:63 http://archive.ubuntu.com/ubuntu artful/main amd64 libjson-glib-1.0-common all 1.2.8-1 [3,648 B]
# Get:64 http://archive.ubuntu.com/ubuntu artful/main amd64 libjson-glib-1.0-0 amd64 1.2.8-1 [60.4 kB]
# Get:65 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-system1.62.0 amd64 1.62.0+dfsg-4build3 [9,212 B]
# Get:66 http://archive.ubuntu.com/ubuntu artful/main amd64 libcapnp-0.5.3 amd64 0.5.3-2ubuntu2 [569 kB]
# Get:67 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-filesystem1.62.0 amd64 1.62.0+dfsg-4build3 [38.6 kB]
# Get:68 http://archive.ubuntu.com/ubuntu artful/main amd64 libmircore1 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [31.5 kB]
# Get:69 http://archive.ubuntu.com/ubuntu artful/main amd64 libmircommon7 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [73.2 kB]
# Get:70 http://archive.ubuntu.com/ubuntu artful/main amd64 libprotobuf-lite10 amd64 3.0.0-9ubuntu5 [97.1 kB]
# Get:71 http://archive.ubuntu.com/ubuntu artful/main amd64 libmirprotobuf3 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [131 kB]
# Get:72 http://archive.ubuntu.com/ubuntu artful/main amd64 xkb-data all 2.19-1.1ubuntu1 [312 kB]
# Get:73 http://archive.ubuntu.com/ubuntu artful/main amd64 libxkbcommon0 amd64 0.7.1-2 [97.2 kB]
# Get:74 http://archive.ubuntu.com/ubuntu artful/main amd64 libmirclient9 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [199 kB]
# Get:75 http://archive.ubuntu.com/ubuntu artful/main amd64 libgraphite2-3 amd64 1.3.10-2 [78.3 kB]
# Get:76 http://archive.ubuntu.com/ubuntu artful/main amd64 libharfbuzz0b amd64 1.4.2-1 [211 kB]
# Get:77 http://archive.ubuntu.com/ubuntu artful/main amd64 libpangoft2-1.0-0 amd64 1.40.12-1 [33.2 kB]
# Get:78 http://archive.ubuntu.com/ubuntu artful/main amd64 libpangocairo-1.0-0 amd64 1.40.12-1 [20.8 kB]
# Get:79 http://archive.ubuntu.com/ubuntu artful/main amd64 libproxy1v5 amd64 0.4.14-3 [50.8 kB]
# Get:80 http://archive.ubuntu.com/ubuntu artful/main amd64 glib-networking-common all 2.54.0-1 [2,960 B]
# Get:81 http://archive.ubuntu.com/ubuntu artful/main amd64 glib-networking-services amd64 2.54.0-1 [8,096 B]
# Get:82 http://archive.ubuntu.com/ubuntu artful/main amd64 gsettings-desktop-schemas all 3.24.1-1ubuntu1 [27.6 kB]
# Get:83 http://archive.ubuntu.com/ubuntu artful/main amd64 glib-networking amd64 2.54.0-1 [52.0 kB]
# Get:84 http://archive.ubuntu.com/ubuntu artful/main amd64 libsoup2.4-1 amd64 2.60.1-1 [289 kB]
# Get:85 http://archive.ubuntu.com/ubuntu artful/main amd64 libsoup-gnome2.4-1 amd64 2.60.1-1 [5,008 B]
# Get:86 http://archive.ubuntu.com/ubuntu artful/main amd64 librest-0.7-0 amd64 0.8.0-2 [31.8 kB]
# Get:87 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-client0 amd64 1.14.0-1ubuntu0.1 [22.5 kB]
# Get:88 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-cursor0 amd64 1.14.0-1ubuntu0.1 [9,890 B]
# Get:89 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-common all 2.4.83-1 [4,938 B]
# Get:90 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm2 amd64 2.4.83-1 [30.6 kB]
# Get:91 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-server0 amd64 1.14.0-1ubuntu0.1 [28.5 kB]
# Get:92 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgbm1 amd64 17.2.8-0ubuntu0~17.10.1 [24.4 kB]
# Get:93 http://archive.ubuntu.com/ubuntu artful/main amd64 libx11-xcb1 amd64 2:1.6.4-3 [9,626 B]
# Get:94 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-dri2-0 amd64 1.12-1ubuntu1 [6,838 B]
# Get:95 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-dri3-0 amd64 1.12-1ubuntu1 [5,156 B]
# Get:96 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-present0 amd64 1.12-1ubuntu1 [5,436 B]
# Get:97 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-sync1 amd64 1.12-1ubuntu1 [8,746 B]
# Get:98 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-xfixes0 amd64 1.12-1ubuntu1 [9,292 B]
# Get:99 http://archive.ubuntu.com/ubuntu artful/main amd64 libxshmfence1 amd64 1.2-1 [5,042 B]
# Get:100 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-amdgpu1 amd64 2.4.83-1 [18.5 kB]
# Get:101 http://archive.ubuntu.com/ubuntu artful/main amd64 libpciaccess0 amd64 0.13.4-1ubuntu1 [17.9 kB]
# Get:102 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-intel1 amd64 2.4.83-1 [59.7 kB]
# Get:103 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-nouveau2 amd64 2.4.83-1 [16.4 kB]
# Get:104 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-radeon1 amd64 2.4.83-1 [21.6 kB]
# Get:105 http://archive.ubuntu.com/ubuntu artful/main amd64 libelf1 amd64 0.170-0.1 [44.3 kB]
# Get:106 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libglapi-mesa amd64 17.2.8-0ubuntu0~17.10.1 [22.2 kB]
# Get:107 http://archive.ubuntu.com/ubuntu artful/main amd64 libllvm5.0 amd64 1:5.0-3 [13.7 MB]
# Get:108 file:/var/cuda-repo-9-2-local  cuda-nvdisasm-9-2 9.2.88-1 [17.4 MB]
# Get:109 http://archive.ubuntu.com/ubuntu artful/main amd64 libsensors4 amd64 1:3.4.0-4 [28.8 kB]
# Get:110 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgl1-mesa-dri amd64 17.2.8-0ubuntu0~17.10.1 [5,707 kB]
# Get:111 file:/var/cuda-repo-9-2-local  cuda-gdb-9-2 9.2.88-1 [2,765 kB]
# Get:112 file:/var/cuda-repo-9-2-local  cuda-nvprof-9-2 9.2.88-1 [4,737 kB]
# Get:113 file:/var/cuda-repo-9-2-local  cuda-memcheck-9-2 9.2.88-1 [137 kB]
# Get:114 file:/var/cuda-repo-9-2-local  cuda-cudart-9-2 9.2.88-1 [97.8 kB]
# Get:115 file:/var/cuda-repo-9-2-local  cuda-driver-dev-9-2 9.2.88-1 [11.1 kB]
# Get:116 file:/var/cuda-repo-9-2-local  cuda-cudart-dev-9-2 9.2.88-1 [718 kB]
# Get:117 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libegl1-mesa amd64 17.2.8-0ubuntu0~17.10.1 [85.3 kB]
# Get:118 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-egl1-mesa amd64 17.2.8-0ubuntu0~17.10.1 [5,778 B]
# Get:119 file:/var/cuda-repo-9-2-local  cuda-cupti-9-2 9.2.88-1 [1,537 kB]
# Get:120 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcomposite1 amd64 1:0.4.4-2 [6,988 B]
# 8% [Working]
# Get:121 http://archive.ubuntu.com/ubuntu artful/main amd64 libxfixes3 amd64 1:5.0.3-1 [10.8 kB]
# Get:122 file:/var/cuda-repo-9-2-local  cuda-gpu-library-advisor-9-2 9.2.88-1 [1,002 kB]
# Get:123 file:/var/cuda-repo-9-2-local  cuda-nvtx-9-2 9.2.88-1 [24.3 kB]
# Get:124 file:/var/cuda-repo-9-2-local  cuda-command-line-tools-9-2 9.2.88-1 [26.3 kB]
# Get:125 file:/var/cuda-repo-9-2-local  cuda-nsight-9-2 9.2.88-1 [2,580 B]
# Get:126 file:/var/cuda-repo-9-2-local  cuda-nvvp-9-2 9.2.88-1 [2,528 B]
# Get:127 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libxcursor1 amd64 1:1.1.14-3ubuntu0.1 [19.8 kB]
# Get:128 http://archive.ubuntu.com/ubuntu artful/main amd64 libxdamage1 amd64 1:1.1.4-3 [6,934 B]
# Get:129 http://archive.ubuntu.com/ubuntu artful/main amd64 libxi6 amd64 2:1.7.9-1 [29.2 kB]
# Get:130 http://archive.ubuntu.com/ubuntu artful/main amd64 libxinerama1 amd64 2:1.1.3-1 [7,908 B]
# Get:131 http://archive.ubuntu.com/ubuntu artful/main amd64 libxrandr2 amd64 2:1.5.1-1 [18.1 kB]
# Get:132 http://archive.ubuntu.com/ubuntu artful/main amd64 hicolor-icon-theme all 0.17-1 [10.3 kB]
# Get:133 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 gtk-update-icon-cache amd64 3.22.25-0ubuntu0.1 [27.6 kB]
# Get:134 file:/var/cuda-repo-9-2-local  cuda-nvrtc-9-2 9.2.88-1 [5,908 kB]
# Get:135 file:/var/cuda-repo-9-2-local  cuda-nvrtc-dev-9-2 9.2.88-1 [9,318 B]
# Get:136 http://archive.ubuntu.com/ubuntu artful/main amd64 libcroco3 amd64 0.6.12-1 [81.3 kB]
# Get:137 http://archive.ubuntu.com/ubuntu artful/main amd64 librsvg2-2 amd64 2.40.18-1 [95.2 kB]
# Get:138 http://archive.ubuntu.com/ubuntu artful/main amd64 librsvg2-common amd64 2.40.18-1 [5,106 B]
# Get:139 http://archive.ubuntu.com/ubuntu artful/main amd64 humanity-icon-theme all 0.6.13 [1,288 kB]
# Get:140 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 ubuntu-mono all 16.10+17.10.20171115-0ubuntu1 [162 kB]
# Get:141 http://archive.ubuntu.com/ubuntu artful/main amd64 adwaita-icon-theme all 3.26.0-0ubuntu2 [3,452 kB]
# Get:142 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgtk-3-0 amd64 3.22.25-0ubuntu0.1 [2,540 kB]
# Get:143 http://archive.ubuntu.com/ubuntu artful/main amd64 libindicator3-7 amd64 16.10.0+16.10.20160913-0ubuntu1 [26.1 kB]
# Get:144 http://archive.ubuntu.com/ubuntu artful/main amd64 libappindicator3-1 amd64 12.10.1+17.04.20170215-0ubuntu2 [19.2 kB]
# Get:145 http://archive.ubuntu.com/ubuntu artful/main amd64 libcdparanoia0 amd64 3.10.2+debian-11 [53.1 kB]
# Get:146 http://archive.ubuntu.com/ubuntu artful/main amd64 libdaemon0 amd64 0.14-6 [16.6 kB]
# Get:147 http://archive.ubuntu.com/ubuntu artful/main amd64 liblzo2-2 amd64 2.08-1.2 [48.7 kB]
# Get:148 http://archive.ubuntu.com/ubuntu artful/main amd64 libmtdev1 amd64 1.1.5-1ubuntu2 [13.8 kB]
# Get:149 http://archive.ubuntu.com/ubuntu artful/main amd64 libmtp-common all 1.1.13-1 [43.6 kB]
# Get:150 http://archive.ubuntu.com/ubuntu artful/main amd64 libusb-1.0-0 amd64 2:1.0.21-2 [43.3 kB]
# Get:151 http://archive.ubuntu.com/ubuntu artful/main amd64 libmtp9 amd64 1.1.13-1 [154 kB]
# Get:152 http://archive.ubuntu.com/ubuntu artful/main amd64 libogg0 amd64 1.3.2-1 [17.2 kB]
# Get:153 http://archive.ubuntu.com/ubuntu artful/main amd64 libspeex1 amd64 1.2~rc1.2-1ubuntu1 [51.3 kB]
# Get:154 http://archive.ubuntu.com/ubuntu artful/main amd64 libtheora0 amd64 1.1.1+dfsg.1-14 [170 kB]
# Get:155 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libvorbis0a amd64 1.3.5-4ubuntu0.2 [86.5 kB]
# Get:156 http://archive.ubuntu.com/ubuntu artful/main amd64 libshout3 amd64 2.3.1-3 [38.1 kB]
# Get:157 http://archive.ubuntu.com/ubuntu artful/main amd64 libstemmer0d amd64 0+svn585-1 [62.1 kB]
# Get:158 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwbclient0 amd64 2:4.6.7+dfsg-1ubuntu3.2 [33.6 kB]
# Get:159 http://archive.ubuntu.com/ubuntu artful/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:160 http://archive.ubuntu.com/ubuntu artful/main amd64 libxxf86vm1 amd64 1:1.1.4-1 [10.6 kB]
# Get:161 http://archive.ubuntu.com/ubuntu artful/main amd64 dbus amd64 1.10.22-1ubuntu1 [144 kB]
# Get:162 http://archive.ubuntu.com/ubuntu artful/main amd64 libglib2.0-data all 2.54.1-1ubuntu1 [4,250 B]
# Get:163 http://archive.ubuntu.com/ubuntu artful/main amd64 libglib2.0-bin amd64 2.54.1-1ubuntu1 [69.8 kB]
# Get:164 file:/var/cuda-repo-9-2-local  cuda-cusolver-9-2 9.2.88-1 [31.1 MB]
# Get:165 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libplymouth4 amd64 0.9.2-3ubuntu20 [85.2 kB]
# Get:166 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 plymouth amd64 0.9.2-3ubuntu20 [108 kB]
# Get:167 http://archive.ubuntu.com/ubuntu artful/universe amd64 lightdm amd64 1.24.0-0ubuntu1 [146 kB]
# Get:168 http://archive.ubuntu.com/ubuntu artful/main amd64 libtalloc2 amd64 2.1.9-2ubuntu1 [35.9 kB]
# Get:169 http://archive.ubuntu.com/ubuntu artful/main amd64 libtdb1 amd64 1.3.13-2build1 [39.1 kB]
# Get:170 http://archive.ubuntu.com/ubuntu artful/main amd64 libtevent0 amd64 0.9.31-1 [28.4 kB]
# Get:171 http://archive.ubuntu.com/ubuntu artful/main amd64 libldb1 amd64 2:1.1.29-2 [110 kB]
# Get:172 http://archive.ubuntu.com/ubuntu artful/main amd64 python-talloc amd64 2.1.9-2ubuntu1 [9,050 B]
# Get:173 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 samba-libs amd64 2:4.6.7+dfsg-1ubuntu3.2 [5,195 kB]
# Get:174 file:/var/cuda-repo-9-2-local  cuda-cusolver-dev-9-2 9.2.88-1 [8,184 kB]
# Get:175 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libsmbclient amd64 2:4.6.7+dfsg-1ubuntu3.2 [54.2 kB]
# Get:176 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 distro-info-data all 0.36ubuntu0.2 [4,418 B]
# Get:177 http://archive.ubuntu.com/ubuntu artful/main amd64 dmsetup amd64 2:1.02.137-2ubuntu3 [71.9 kB]
# Get:178 http://archive.ubuntu.com/ubuntu artful/main amd64 eject amd64 2.1.5+deb1+cvs20081104-13.2 [22.8 kB]
# Get:179 http://archive.ubuntu.com/ubuntu artful/main amd64 libmagic-mgc amd64 1:5.32-1 [184 kB]
# Get:180 http://archive.ubuntu.com/ubuntu artful/main amd64 libmagic1 amd64 1:5.32-1 [68.4 kB]
# Get:181 http://archive.ubuntu.com/ubuntu artful/main amd64 file amd64 1:5.32-1 [22.0 kB]
# Get:182 http://archive.ubuntu.com/ubuntu artful/main amd64 libmnl0 amd64 1.0.4-2 [12.3 kB]
# Get:183 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 iproute2 amd64 4.9.0-1ubuntu2.1 [628 kB]
# Get:184 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libisc-export160 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [155 kB]
# 13% [184 libisc-export160 0 B/155 kB 0%]
# Get:185 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libdns-export162 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [671 kB]
# Get:186 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 isc-dhcp-client amd64 4.3.5-3ubuntu2.3 [244 kB]
# Get:187 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 isc-dhcp-common amd64 4.3.5-3ubuntu2.3 [45.8 kB]
# Get:188 http://archive.ubuntu.com/ubuntu artful/main amd64 kmod amd64 24-1ubuntu2 [88.7 kB]
# Get:189 http://archive.ubuntu.com/ubuntu artful/main amd64 libatm1 amd64 1:2.5.1-2 [21.7 kB]
# Get:190 http://archive.ubuntu.com/ubuntu artful/main amd64 libcap2-bin amd64 1:2.25-1.1 [20.5 kB]
# Get:191 http://archive.ubuntu.com/ubuntu artful/main amd64 libfribidi0 amd64 0.19.7-1 [25.1 kB]
# Get:192 http://archive.ubuntu.com/ubuntu artful/main amd64 libjson-c3 amd64 0.12.1-1.2 [21.5 kB]
# Get:193 http://archive.ubuntu.com/ubuntu artful/main amd64 libslang2 amd64 2.3.1-5ubuntu1 [422 kB]
# Get:194 http://archive.ubuntu.com/ubuntu artful/main amd64 libnewt0.52 amd64 0.52.18-3ubuntu3 [40.9 kB]
# Get:195 file:/var/cuda-repo-9-2-local  cuda-cublas-9-2 9.2.88-1 [24.9 MB]
# Get:196 http://archive.ubuntu.com/ubuntu artful/main amd64 libpam-cap amd64 1:2.25-1.1 [7,190 B]
# Get:197 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libpam-systemd amd64 234-2ubuntu12.4 [111 kB]
# Get:198 http://archive.ubuntu.com/ubuntu artful/main amd64 libtext-iconv-perl amd64 1.7-5build6 [13.0 kB]
# Get:199 http://archive.ubuntu.com/ubuntu artful/main amd64 libxtables12 amd64 1.6.1-2ubuntu1 [27.8 kB]
# Get:200 http://archive.ubuntu.com/ubuntu artful/main amd64 libyaml-0-2 amd64 0.1.7-2ubuntu3 [47.2 kB]
# Get:201 http://archive.ubuntu.com/ubuntu artful/main amd64 lsb-release all 9.20160110ubuntu5 [11.1 kB]
# Get:202 http://archive.ubuntu.com/ubuntu artful/main amd64 sudo amd64 1.8.20p2-1ubuntu1 [415 kB]
# Get:203 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libaccountsservice0 amd64 0.6.42-0ubuntu3.1 [70.2 kB]
# Get:204 http://archive.ubuntu.com/ubuntu artful/main amd64 libpolkit-gobject-1-0 amd64 0.105-18 [36.8 kB]
# Get:205 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 accountsservice amd64 0.6.42-0ubuntu3.1 [59.8 kB]
# Get:206 http://archive.ubuntu.com/ubuntu artful/main amd64 libgeoip1 amd64 1.6.11-2ubuntu1 [71.7 kB]
# Get:207 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libisc160 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [219 kB]
# Get:208 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libdns162 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [883 kB]
# Get:209 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libisccc140 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [16.6 kB]
# Get:210 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libisccfg140 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [40.9 kB]
# Get:211 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libbind9-140 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [23.9 kB]
# Get:212 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 liblwres141 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [34.5 kB]
# Get:213 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 bind9-host amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [50.1 kB]
# Get:214 http://archive.ubuntu.com/ubuntu artful/main amd64 dosfstools amd64 4.1-1 [58.1 kB]
# Get:215 http://archive.ubuntu.com/ubuntu artful/main amd64 geoip-database all 20170912-1 [2,225 kB]
# Get:216 http://archive.ubuntu.com/ubuntu artful/main amd64 gettext-base amd64 0.19.8.1-4ubuntu1 [49.4 kB]
# Get:217 http://archive.ubuntu.com/ubuntu artful/main amd64 libgirepository-1.0-1 amd64 1.54.1-1 [82.1 kB]
# Get:218 http://archive.ubuntu.com/ubuntu artful/main amd64 gir1.2-glib-2.0 amd64 1.54.1-1 [131 kB]
# Get:219 http://archive.ubuntu.com/ubuntu artful/main amd64 libip6tc0 amd64 1.6.1-2ubuntu1 [19.9 kB]
# Get:220 http://archive.ubuntu.com/ubuntu artful/main amd64 libiptc0 amd64 1.6.1-2ubuntu1 [9,254 B]
# Get:221 http://archive.ubuntu.com/ubuntu artful/main amd64 libnetfilter-conntrack3 amd64 1.0.6-2 [37.8 kB]
# Get:222 http://archive.ubuntu.com/ubuntu artful/main amd64 iptables amd64 1.6.1-2ubuntu1 [269 kB]
# Get:223 http://archive.ubuntu.com/ubuntu artful/main amd64 iso-codes all 3.75-1 [2,339 kB]
# Get:224 http://archive.ubuntu.com/ubuntu artful/main amd64 libdbus-glib-1-2 amd64 0.108-2 [67.1 kB]
# Get:225 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libparted2 amd64 3.2-18ubuntu0.1 [123 kB]
# Get:226 http://archive.ubuntu.com/ubuntu artful/main amd64 libpcap0.8 amd64 1.8.1-5ubuntu1 [118 kB]
# Get:227 http://archive.ubuntu.com/ubuntu artful/main amd64 libpci3 amd64 1:3.5.2-1ubuntu1 [24.1 kB]
# Get:228 http://archive.ubuntu.com/ubuntu artful/main amd64 libxmuu1 amd64 2:1.1.2-2 [9,674 B]
# Get:229 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 parted amd64 3.2-18ubuntu0.1 [42.3 kB]
# Get:230 http://archive.ubuntu.com/ubuntu artful/main amd64 pciutils amd64 1:3.5.2-1ubuntu1 [247 kB]
# Get:231 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 plymouth-theme-ubuntu-text amd64 0.9.2-3ubuntu20 [8,968 B]
# Get:232 http://archive.ubuntu.com/ubuntu artful/main amd64 psmisc amd64 23.1-1 [51.5 kB]
# Get:233 http://archive.ubuntu.com/ubuntu artful/main amd64 python-apt-common all 1.4.0~beta3build2 [17.1 kB]
# Get:234 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-apt amd64 1.4.0~beta3build2 [141 kB]
# Get:235 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-dbus amd64 1.2.4-1build3 [84.1 kB]
# Get:236 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-gi amd64 3.24.1-2build1 [153 kB]
# Get:237 http://archive.ubuntu.com/ubuntu artful/main amd64 xauth amd64 1:1.0.9-1ubuntu2 [22.7 kB]
# Get:238 http://archive.ubuntu.com/ubuntu artful/main amd64 acpid amd64 1:2.0.28-1ubuntu1 [36.5 kB]
# Get:239 http://archive.ubuntu.com/ubuntu artful/main amd64 libgee-0.8-2 amd64 0.20.0-1 [211 kB]
# Get:240 http://archive.ubuntu.com/ubuntu artful/universe amd64 libunity-control-center1 amd64 15.04.0+17.10.20170930-0ubuntu1 [80.6 kB]
# Get:241 http://archive.ubuntu.com/ubuntu artful/main amd64 libwhoopsie-preferences0 amd64 0.19 [13.9 kB]
# ...
# Setting up xserver-xorg-input-wacom (1:0.34.0-0ubuntu2) ...
# Setting up freeglut3-dev:amd64 (2.8.1-3) ...
# Setting up xserver-xorg-video-ati (1:7.10.0-1) ...
# Setting up libcuda1-396 (396.26-0ubuntu1) ...
# Setting up pulseaudio (1:10.0-2ubuntu3.1) ...
# Adding user pulse to group audio
# Setting up xserver-xorg-video-intel (2:2.99.917+git20170309-0ubuntu1) ...
# Setting up gvfs-backends (1.34.1-1ubuntu1) ...
# Setting up cuda-samples-9-2 (9.2.88-1) ...
# Setting up xserver-xorg-video-qxl (0.1.5-2build1) ...
# Setting up cuda-documentation-9-2 (9.2.88-1) ...
# Setting up nvidia-396-dev (396.26-0ubuntu1) ...
# Setting up nvidia-opencl-icd-396 (396.26-0ubuntu1) ...
# Setting up libcogl20:amd64 (1.22.2-2) ...
# Setting up xserver-xorg-video-nouveau (1:1.0.15-2) ...
# Setting up xserver-xorg-video-fbdev (1:0.4.4-1build6) ...
# Setting up libcanberra-pulse:amd64 (0.30-3ubuntu1) ...
# Setting up xserver-xorg-input-libinput (0.25.0-0ubuntu1) ...
# Setting up xserver-xorg-video-vmware (1:13.2.1-1build1) ...
# Setting up xserver-xorg (1:7.7+19ubuntu3) ...
# Setting up indicator-sound (12.10.2+17.10.20170829.1-0ubuntu1) ...
# Setting up libebook-1.2-19:amd64 (3.26.1-1ubuntu1) ...
# Setting up libcogl-pango20:amd64 (1.22.2-2) ...
# Setting up xserver-xorg-input-all (1:7.7+19ubuntu3) ...
# Setting up libcogl-path20:amd64 (1.22.2-2) ...
# Setting up xserver-xorg-video-all (1:7.7+19ubuntu3) ...
# Setting up openjdk-8-jre-headless:amd64 (8u171-b11-0ubuntu0.17.10.1) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/rmid to provide /usr/bin/rmid (rmid) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/keytool to provide /usr/bin/keytool (keytool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/jjs to provide /usr/bin/jjs (jjs) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/pack200 to provide /usr/bin/pack200 (pack200) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/rmiregistry to provide /usr/bin/rmiregistry (rmiregistry) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/unpack200 to provide /usr/bin/unpack200 (unpack200) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/lib/jexec to provide /usr/bin/jexec (jexec) in auto mode
# Setting up adwaita-icon-theme (3.26.0-0ubuntu2) ...
# update-alternatives: using /usr/share/icons/Adwaita/cursor.theme to provide /usr/share/icons/default/index.theme (x-cursor-theme) in auto mode
# Setting up libgtk2.0-0:amd64 (2.24.31-2ubuntu1) ...
# Setting up ca-certificates-java (20170930) ...
# Adding debian:Entrust.net_Premium_2048_Secure_Server_CA.pem
# Adding debian:CFCA_EV_ROOT.pem
# Adding debian:OpenTrust_Root_CA_G1.pem
# Adding debian:OpenTrust_Root_CA_G2.pem
# Adding debian:Camerfirma_Global_Chambersign_Root.pem
# Adding debian:Certplus_Root_CA_G1.pem
# Adding debian:NetLock_Arany_=Class_Gold=_Főtanúsítvány.pem
# Adding debian:Swisscom_Root_CA_2.pem
# Adding debian:ACCVRAIZ1.pem
# Adding debian:Hongkong_Post_Root_CA_1.pem
# Adding debian:Camerfirma_Chambers_of_Commerce_Root.pem
# Adding debian:thawte_Primary_Root_CA_-_G3.pem
# Adding debian:Sonera_Class_2_Root_CA.pem
# Adding debian:OpenTrust_Root_CA_G3.pem
# Adding debian:Starfield_Class_2_CA.pem
# Adding debian:QuoVadis_Root_CA_2_G3.pem
# Adding debian:Verisign_Class_3_Public_Primary_Certification_Authority_-_G3.pem
# Adding debian:Certinomis_-_Root_CA.pem
# Adding debian:CA_Disig_Root_R1.pem
# Adding debian:Cybertrust_Global_Root.pem
# Adding debian:USERTrust_RSA_Certification_Authority.pem
# Adding debian:Comodo_Trusted_Services_root.pem
# Adding debian:ePKI_Root_Certification_Authority.pem
# Adding debian:Certplus_Class_2_Primary_CA.pem
# Adding debian:GlobalSign_Root_CA_-_R3.pem
# Adding debian:Amazon_Root_CA_3.pem
# Adding debian:Amazon_Root_CA_2.pem
# Adding debian:AddTrust_Low-Value_Services_Root.pem
# Adding debian:Atos_TrustedRoot_2011.pem
# Adding debian:LuxTrust_Global_Root_2.pem
# Adding debian:CA_Disig_Root_R2.pem
# Adding debian:China_Internet_Network_Information_Center_EV_Certificates_Root.pem
# Adding debian:Entrust_Root_Certification_Authority_-_EC1.pem
# Adding debian:Amazon_Root_CA_1.pem
# Adding debian:GlobalSign_ECC_Root_CA_-_R5.pem
# Adding debian:Buypass_Class_2_Root_CA.pem
# Adding debian:VeriSign_Universal_Root_Certification_Authority.pem
# Adding debian:Chambers_of_Commerce_Root_-_2008.pem
# Adding debian:Certum_Trusted_Network_CA_2.pem
# Adding debian:Entrust_Root_Certification_Authority_-_G2.pem
# Adding debian:ISRG_Root_X1.pem
# Adding debian:IdenTrust_Public_Sector_Root_CA_1.pem
# Adding debian:QuoVadis_Root_CA_3_G3.pem
# Adding debian:GeoTrust_Universal_CA_2.pem
# Adding debian:Autoridad_de_Certificacion_Firmaprofesional_CIF_A62634068.pem
# Adding debian:DST_Root_CA_X3.pem
# Adding debian:T-TeleSec_GlobalRoot_Class_3.pem
# Adding debian:DigiCert_Global_Root_CA.pem
# Adding debian:AffirmTrust_Premium.pem
# Adding debian:DigiCert_High_Assurance_EV_Root_CA.pem
# Adding debian:Certum_Root_CA.pem
# Adding debian:D-TRUST_Root_Class_3_CA_2_2009.pem
# Adding debian:Entrust_Root_Certification_Authority.pem
# Adding debian:AddTrust_Public_Services_Root.pem
# Adding debian:ACEDICOM_Root.pem
# Adding debian:Swisscom_Root_EV_CA_2.pem
# Adding debian:AddTrust_External_Root.pem
# Adding debian:Certum_Trusted_Network_CA.pem
# Adding debian:TUBITAK_Kamu_SM_SSL_Kok_Sertifikasi_-_Surum_1.pem
# Adding debian:GeoTrust_Universal_CA.pem
# Adding debian:SecureSign_RootCA11.pem
# Adding debian:GlobalSign_ECC_Root_CA_-_R4.pem
# Adding debian:GeoTrust_Global_CA.pem
# Adding debian:AC_RAIZ_FNMT-RCM.pem
# Adding debian:DigiCert_Global_Root_G3.pem
# Adding debian:Trustis_FPS_Root_CA.pem
# Adding debian:AffirmTrust_Premium_ECC.pem
# Adding debian:EE_Certification_Centre_Root_CA.pem
# Adding debian:T-TeleSec_GlobalRoot_Class_2.pem
# Adding debian:QuoVadis_Root_CA_1_G3.pem
# Adding debian:AffirmTrust_Commercial.pem
# Adding debian:Certplus_Root_CA_G2.pem
# Adding debian:Microsec_e-Szigno_Root_CA_2009.pem
# Adding debian:GlobalSign_Root_CA.pem
# Adding debian:DigiCert_Assured_ID_Root_G2.pem
# Adding debian:Visa_eCommerce_Root.pem
# Adding debian:Hellenic_Academic_and_Research_Institutions_RootCA_2015.pem
# Adding debian:OISTE_WISeKey_Global_Root_GB_CA.pem
# Adding debian:AddTrust_Qualified_Certificates_Root.pem
# Adding debian:TeliaSonera_Root_CA_v1.pem
# Adding debian:PSCProcert.pem
# Adding debian:IdenTrust_Commercial_Root_CA_1.pem
# Adding debian:Staat_der_Nederlanden_Root_CA_-_G2.pem
# Adding debian:COMODO_RSA_Certification_Authority.pem
# Adding debian:TWCA_Global_Root_CA.pem
# Adding debian:Secure_Global_CA.pem
# Adding debian:Security_Communication_EV_RootCA1.pem
# Adding debian:SwissSign_Gold_CA_-_G2.pem
# Adding debian:Comodo_Secure_Services_root.pem
# Adding debian:QuoVadis_Root_CA_2.pem
# Adding debian:Actalis_Authentication_Root_CA.pem
# Adding debian:TÜBİTAK_UEKAE_Kök_Sertifika_Hizmet_Sağlayıcısı_-_Sürüm_3.pem
# Adding debian:QuoVadis_Root_CA_3.pem
# Adding debian:Staat_der_Nederlanden_Root_CA_-_G3.pem
# Adding debian:GlobalSign_Root_CA_-_R2.pem
# Adding debian:Global_Chambersign_Root_-_2008.pem
# Adding debian:Deutsche_Telekom_Root_CA_2.pem
# Adding debian:GeoTrust_Primary_Certification_Authority_-_G3.pem
# Adding debian:GeoTrust_Primary_Certification_Authority_-_G2.pem
# Adding debian:Go_Daddy_Class_2_CA.pem
# Adding debian:XRamp_Global_CA_Root.pem
# Adding debian:Izenpe.com.pem
# Adding debian:Go_Daddy_Root_Certificate_Authority_-_G2.pem
# Adding debian:Security_Communication_RootCA2.pem
# Adding debian:Taiwan_GRCA.pem
# Adding debian:AffirmTrust_Networking.pem
# Adding debian:COMODO_ECC_Certification_Authority.pem
# Adding debian:USERTrust_ECC_Certification_Authority.pem
# Adding debian:EC-ACC.pem
# Adding debian:GeoTrust_Primary_Certification_Authority.pem
# Adding debian:SwissSign_Silver_CA_-_G2.pem
# Adding debian:TURKTRUST_Certificate_Services_Provider_Root_2007.pem
# Adding debian:DigiCert_Assured_ID_Root_G3.pem
# Adding debian:Certinomis_-_Autorité_Racine.pem
# Adding debian:GeoTrust_Global_CA_2.pem
# Adding debian:Security_Communication_Root_CA.pem
# Adding debian:SecureTrust_CA.pem
# Adding debian:Hellenic_Academic_and_Research_Institutions_RootCA_2011.pem
# Adding debian:thawte_Primary_Root_CA_-_G2.pem
# Adding debian:Staat_der_Nederlanden_EV_Root_CA.pem
# Adding debian:DigiCert_Assured_ID_Root_CA.pem
# Adding debian:DigiCert_Trusted_Root_G4.pem
# Adding debian:VeriSign_Class_3_Public_Primary_Certification_Authority_-_G5.pem
# Adding debian:Certigna.pem
# Adding debian:Network_Solutions_Certificate_Authority.pem
# Adding debian:TWCA_Root_Certification_Authority.pem
# Adding debian:Swisscom_Root_CA_1.pem
# Adding debian:Baltimore_CyberTrust_Root.pem
# Adding debian:thawte_Primary_Root_CA.pem
# Adding debian:QuoVadis_Root_CA.pem
# Adding debian:VeriSign_Class_3_Public_Primary_Certification_Authority_-_G4.pem
# Adding debian:OISTE_WISeKey_Global_Root_GA_CA.pem
# Adding debian:Amazon_Root_CA_4.pem
# Adding debian:D-TRUST_Root_Class_3_CA_2_EV_2009.pem
# Adding debian:COMODO_Certification_Authority.pem
# Adding debian:DigiCert_Global_Root_G2.pem
# Adding debian:certSIGN_ROOT_CA.pem
# Adding debian:DST_ACES_CA_X6.pem
# Adding debian:Starfield_Root_Certificate_Authority_-_G2.pem
# Adding debian:SZAFIR_ROOT_CA2.pem
# Adding debian:CNNIC_ROOT.pem
# Adding debian:TÜRKTRUST_Elektronik_Sertifika_Hizmet_Sağlayıcısı_H5.pem
# Adding debian:Starfield_Services_Root_Certificate_Authority_-_G2.pem
# Adding debian:UTN_USERFirst_Hardware_Root_CA.pem
# Adding debian:Hellenic_Academic_and_Research_Institutions_ECC_RootCA_2015.pem
# Adding debian:Buypass_Class_3_Root_CA.pem
# Adding debian:E-Tugra_Certification_Authority.pem
# Adding debian:Comodo_AAA_Services_root.pem
# done.
# Setting up libgail18:amd64 (2.24.31-2ubuntu1) ...
# Setting up ibus-gtk:amd64 (1.5.14-2ubuntu1) ...
# Setting up libgail-common:amd64 (2.24.31-2ubuntu1) ...
# Setting up humanity-icon-theme (0.6.13) ...
# Setting up libgtk-3-0:amd64 (3.22.25-0ubuntu0.1) ...
# Setting up mousetweaks (3.12.0-1ubuntu3) ...
# Setting up libgtk-3-bin (3.22.25-0ubuntu0.1) ...
# Setting up openjdk-8-jre:amd64 (8u171-b11-0ubuntu0.17.10.1) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/policytool to provide /usr/bin/policytool (policytool) in auto mode
# Setting up libgcr-ui-3-1:amd64 (3.20.0-5.1ubuntu1) ...
# Setting up policykit-1-gnome (0.105-6ubuntu2) ...
# Setting up screen-resolution-extra (0.17.1.1) ...
# Setting up libtimezonemap1:amd64 (0.4.5) ...
# Setting up libcanberra-gtk3-0:amd64 (0.30-3ubuntu1) ...
# Setting up libido3-0.1-0:amd64 (13.10.0+17.04.20161028-0ubuntu1) ...
# Setting up libnma0:amd64 (1.8.4-1ubuntu1) ...
# Setting up libunity-control-center1 (15.04.0+17.10.20170930-0ubuntu1) ...
# Setting up libpanel-applet3 (1:3.24.1-1ubuntu2) ...
# Setting up gnome-power-manager (3.25.90-1) ...
# Setting up gcr (3.20.0-5.1ubuntu1) ...
# Setting up libgnome-desktop-3-12:amd64 (3.26.2-0ubuntu0.1) ...
# Setting up libgnomekbd8:amd64 (3.26.0-2) ...
# Setting up notification-daemon (3.20.0-1) ...
# Setting up default-jre-headless (2:1.8-59ubuntu1) ...
# Setting up libclutter-1.0-0:amd64 (1.26.2+dfsg-3ubuntu1) ...
# Setting up libgtk2.0-bin (2.24.31-2ubuntu1) ...
# Setting up libindicator3-7 (16.10.0+16.10.20160913-0ubuntu1) ...
# Setting up gir1.2-gtk-3.0:amd64 (3.22.25-0ubuntu0.1) ...
# Setting up activity-log-manager (0.9.7-0ubuntu26) ...
# Setting up libgweather-3-6:amd64 (3.26.0-1ubuntu0.1) ...
# Setting up libcanberra-gtk3-module:amd64 (0.30-3ubuntu1) ...
# Setting up ubuntu-mono (16.10+17.10.20171115-0ubuntu1) ...
# Setting up gnome-screensaver (3.6.1-7ubuntu6) ...
# Setting up libwebkit2gtk-4.0-37:amd64 (2.20.2-0ubuntu0.17.10.1) ...
# Setting up system-config-printer-common (1.5.9+20170825-0ubuntu1) ...
# Setting up default-jre (2:1.8-59ubuntu1) ...
# Setting up libnm-gtk0:amd64 (1.8.4-1ubuntu1) ...
# Setting up cuda-nsight-9-2 (9.2.88-1) ...
# Setting up libgnome-bluetooth13:amd64 (3.26.1-1) ...
# Setting up libunity-settings-daemon1:amd64 (15.04.1+17.10.20171003-0ubuntu1) ...
# Setting up ibus-gtk3:amd64 (1.5.14-2ubuntu1) ...
# Setting up libyelp0:amd64 (3.26.0-1ubuntu1) ...
# Setting up indicator-applet (12.10.2+17.10.20170425-0ubuntu1) ...
# Setting up indicator-keyboard (0.0.0+17.10.20170906-0ubuntu1) ...
# Setting up nvidia-settings (396.26-0ubuntu1) ...
# Setting up cuda-drivers (396.26-1) ...
# Setting up ibus (1.5.14-2ubuntu1) ...
# Setting up pinentry-gnome3 (1.0.0-2) ...
# Setting up gnome-bluetooth (3.26.1-1) ...
# Setting up gnome-keyring (3.20.1-1ubuntu1) ...
# Setting up libclutter-gtk-1.0-0:amd64 (1.8.4-2) ...
# Setting up libclutter-gst-3.0-0:amd64 (3.0.24-1) ...
# Setting up gkbd-capplet (3.26.0-2) ...
# Setting up gnome-session-bin (3.26.1-0ubuntu6) ...
# update-alternatives: using /usr/bin/gnome-session to provide /usr/bin/x-session-manager (x-session-manager) in auto mode
# Setting up cuda-runtime-9-2 (9.2.88-1) ...
# Setting up system-config-printer (1.5.9+20170825-0ubuntu1) ...
# Setting up libappindicator3-1 (12.10.1+17.04.20170215-0ubuntu2) ...
# Setting up yelp (3.26.0-1ubuntu1) ...
# Setting up evolution-data-server (3.26.1-1ubuntu1) ...
# Setting up gstreamer1.0-clutter-3.0 (3.0.24-1) ...
# Setting up libcheese8:amd64 (3.26.0-0ubuntu1) ...
# Setting up zenity (3.24.0-1) ...
# Setting up cuda-nvvp-9-2 (9.2.88-1) ...
# Setting up unity-settings-daemon (15.04.1+17.10.20171003-0ubuntu1) ...
# Setting up libcheese-gtk25:amd64 (3.26.0-0ubuntu1) ...
# Setting up indicator-application (12.10.1+17.04.20161201-0ubuntu1) ...
# Setting up network-manager-gnome (1.8.4-1ubuntu1) ...
# Setting up cuda-demo-suite-9-2 (9.2.88-1) ...
# Setting up cuda-visual-tools-9-2 (9.2.88-1) ...
# Setting up unity-greeter (17.10.0-0ubuntu1) ...
# Setting up unity-control-center (15.04.0+17.10.20170930-0ubuntu1) ...
# Setting up cuda-tools-9-2 (9.2.88-1) ...
# Setting up cuda-toolkit-9-2 (9.2.88-1) ...
# Setting up indicator-bluetooth (0.0.6+17.10.20170605-0ubuntu3) ...
# Setting up cuda-9-2 (9.2.88-1) ...
# Setting up cuda (9.2.88-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Processing triggers for systemd (234-2ubuntu12.4) ...
# Processing triggers for dictionaries-common (1.27.2) ...
# aspell-autobuildhash: processing: en [en-common].
# aspell-autobuildhash: processing: en [en-variant_0].
# aspell-autobuildhash: processing: en [en-variant_1].
# aspell-autobuildhash: processing: en [en-variant_2].
# aspell-autobuildhash: processing: en [en-w_accents-only].
# aspell-autobuildhash: processing: en [en-wo_accents-only].
# aspell-autobuildhash: processing: en [en_AU-variant_0].
# aspell-autobuildhash: processing: en [en_AU-variant_1].
# aspell-autobuildhash: processing: en [en_AU-w_accents-only].
# aspell-autobuildhash: processing: en [en_AU-wo_accents-only].
# aspell-autobuildhash: processing: en [en_CA-variant_0].
# aspell-autobuildhash: processing: en [en_CA-variant_1].
# aspell-autobuildhash: processing: en [en_CA-w_accents-only].
# aspell-autobuildhash: processing: en [en_CA-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-variant_0].
# aspell-autobuildhash: processing: en [en_GB-variant_1].
# aspell-autobuildhash: processing: en [en_US-w_accents-only].
# aspell-autobuildhash: processing: en [en_US-wo_accents-only].
# Processing triggers for dbus (1.10.22-1ubuntu1) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.36.11-1ubuntu0.1) ...
# Processing triggers for ca-certificates (20170717) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
#
# done.
# done.

# %%
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'

# %% [markdown]
# ## Verify CUDA installation

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Wed_Apr_11_23:16:29_CDT_2018
# Cuda compilation tools, release 9.2, V9.2.88

# %% [markdown]
# # Install PyTorch, Torchvision, Tensorboard, TensorboardX, cffi, tqdm

# %%
# !pip3 install http://download.pytorch.org/whl/cu91/torch-0.4.0-cp36-cp36m-linux_x86_64.whl 
# !pip3 install torchvision
# Out:
# Collecting torch==0.4.0 from http://download.pytorch.org/whl/cu91/torch-0.4.0-cp36-cp36m-linux_x86_64.whl
#   Downloading http://download.pytorch.org/whl/cu91/torch-0.4.0-cp36-cp36m-linux_x86_64.whl (538.9MB)
#     100% |████████████████████████████████| 538.9MB 50.3MB/s
# tcmalloc: large alloc 1073750016 bytes == 0x5caca000 @  0x7fb6603be1c4 0x46d6a4 0x5fcbcc 0x4c494d 0x54f3c4 0x553aaf 0x54e4c8 0x54f4f6 0x553aaf 0x54efc1 0x54f24d 0x553aaf 0x54efc1 0x54f24d 0x553aaf 0x54efc1 0x54f24d 0x551ee0 0x54e4c8 0x54f4f6 0x553aaf 0x54efc1 0x54f24d 0x551ee0 0x54efc1 0x54f24d 0x551ee0 0x54e4c8 0x54f4f6 0x553aaf 0x54e4c8
# Installing collected packages: torch
# Successfully installed torch-0.4.0
# Collecting torchvision
#   Downloading https://files.pythonhosted.org/packages/ca/0d/f00b2885711e08bd71242ebe7b96561e6f6d01fdb4b9dcf4d37e2e13c5e1/torchvision-0.2.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 4.5MB/s
# Collecting pillow>=4.1.1 (from torchvision)
#   Downloading https://files.pythonhosted.org/packages/5f/4b/8b54ab9d37b93998c81b364557dff9f61972c0f650efa0ceaf470b392740/Pillow-5.1.0-cp36-cp36m-manylinux1_x86_64.whl (2.0MB)
#     100% |████████████████████████████████| 2.0MB 14.4MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.14.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchvision) (0.4.0)
# Installing collected packages: pillow, torchvision
#   Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
#       Successfully uninstalled Pillow-4.0.0
# Successfully installed pillow-5.1.0 torchvision-0.2.1

# %%
# !pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading https://files.pythonhosted.org/packages/c5/22/43f4f0318f7c68a1000dbb700a353b745584bc2397437832d15ba69ea5f1/tensorboardX-1.2-py2.py3-none-any.whl (44kB)
#     100% |████████████████████████████████| 51kB 4.8MB/s
# Requirement already satisfied: protobuf>=0.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.5.2.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.14.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=0.3.2->tensorboardX) (39.2.0)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-1.2

# %%
# !pip3 install tensorboard-pytorch
# Out:
# Collecting tensorboard-pytorch
#   Downloading https://files.pythonhosted.org/packages/6e/d6/b8540153f69a8720b2f032fe8c7504ee66c8c0bce9103c272bd67c8e8c77/tensorboard_pytorch-0.7.1-py2.py3-none-any.whl (72kB)
#     100% |████████████████████████████████| 81kB 7.2MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboard-pytorch) (1.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboard-pytorch) (1.14.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from tensorboard-pytorch) (3.5.2.post1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->tensorboard-pytorch) (39.2.0)
# Installing collected packages: tensorboard-pytorch
# Successfully installed tensorboard-pytorch-0.7.1

# %%
# !pip3 install cffi
# Out:
# Collecting cffi
#   Downloading https://files.pythonhosted.org/packages/6d/c0/47db8f624f3e4e2f3f27be03a93379d1ba16a1450a7b1aacfa0366e2c0dd/cffi-1.11.5-cp36-cp36m-manylinux1_x86_64.whl (421kB)
#     100% |████████████████████████████████| 430kB 20.6MB/s
# Collecting pycparser (from cffi)
#   Downloading https://files.pythonhosted.org/packages/8c/2d/aad7f16146f4197a11f8e91fb81df177adcc2073d36a17b1491fd09df6ed/pycparser-2.18.tar.gz (245kB)
#     100% |████████████████████████████████| 256kB 25.7MB/s
# Building wheels for collected packages: pycparser
# done
#   Stored in directory: /content/.cache/pip/wheels/c0/a1/27/5ba234bd77ea5a290cbf6d675259ec52293193467a12ef1f46
# Successfully built pycparser
# Installing collected packages: pycparser, cffi
# Successfully installed cffi-1.11.5 pycparser-2.18

# %%
# !pip3 install tqdm
# Out:
# Collecting tqdm
#   Downloading https://files.pythonhosted.org/packages/93/24/6ab1df969db228aed36a648a8959d1027099ce45fad67532b9673d533318/tqdm-4.23.4-py2.py3-none-any.whl (42kB)
#     100% |████████████████████████████████| 51kB 5.1MB/s
# Installing collected packages: tqdm
# Successfully installed tqdm-4.23.4

# %% [markdown]
# # Clone Repo

# %%
# !git clone https://github.com/ansleliu/LightNet.git
# Out:
# Cloning into 'LightNet'...
# remote: Counting objects: 329, done.
# remote: Total 329 (delta 0), reused 0 (delta 0), pack-reused 329
# Receiving objects: 100% (329/329), 89.76 MiB | 21.42 MiB/s, done.
# Resolving deltas: 100% (140/140), done.

# %% [markdown]
# ## build inplace_abn

# %%
cd /content/LightNet/modules
# Out:
# /content/LightNet/modules

# %%
#!sh build.sh

# %%
# !python3 build.py
# Out:
# generating /tmp/tmp0vbs47p9/__ext.c
# setting the current directory to '/tmp/tmp0vbs47p9'
# running build_ext
# building '__ext' extension
# creating content
# creating content/LightNet
# creating content/LightNet/modules
# creating content/LightNet/modules/src
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -g -fdebug-prefix-map=/build/python3.6-sXpGnM/python3.6-3.6.3=. -specs=/usr/share/dpkg/no-pie-compile.specs -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/torch/utils/ffi/../../lib/include -I/usr/local/lib/python3.6/dist-packages/torch/utils/ffi/../../lib/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/utils/ffi/../../lib/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c __ext.c -o ./__ext.o -std=c++11
# cc1: warning: command line option ‘-std=c++11’ is valid for C++/ObjC++ but not for C
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -g -fdebug-prefix-map=/build/python3.6-sXpGnM/python3.6-3.6.3=. -specs=/usr/share/dpkg/no-pie-compile.specs -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/torch/utils/ffi/../../lib/include -I/usr/local/lib/python3.6/dist-packages/torch/utils/ffi/../../lib/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/utils/ffi/../../lib/include/THC -I/usr/local/cuda/include -I/usr/include/python3.6m -c /content/LightNet/modules/src/lib_cffi.cpp -o ./content/LightNet/modules/src/lib_cffi.o -std=c++11
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -specs=/usr/share/dpkg/no-pie-link.specs -Wl,-z,relro -Wl,-Bsymbolic-functions -specs=/usr/share/dpkg/no-pie-link.specs -Wl,-z,relro -g -fdebug-prefix-map=/build/python3.6-sXpGnM/python3.6-3.6.3=. -specs=/usr/share/dpkg/no-pie-compile.specs -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 ./__ext.o ./content/LightNet/modules/src/lib_cffi.o /content/LightNet/modules/src/bn.o -o ./__ext.so

# %% [markdown]
# ## install pytorch-encoding

# %%
cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/zhanghang1989/PyTorch-Encoding
# Out:
# Cloning into 'PyTorch-Encoding'...
# remote: Counting objects: 1940, done.
# remote: Compressing objects: 100% (226/226), done.
# remote: Total 1940 (delta 196), reused 319 (delta 163), pack-reused 1546
# Receiving objects: 100% (1940/1940), 23.11 MiB | 20.65 MiB/s, done.
# Resolving deltas: 100% (1106/1106), done.

# %%
cd PyTorch-Encoding/
# Out:
# /content/PyTorch-Encoding

# %%
# !python3 setup.py install
# Out:
# running install
# -- Building version 0.4.2+9bc7053
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/encoding
# copying encoding/parallel.py -> build/lib/encoding
# copying encoding/__init__.py -> build/lib/encoding
# copying encoding/version.py -> build/lib/encoding
# creating build/lib/encoding/nn
# copying encoding/nn/__init__.py -> build/lib/encoding/nn
# copying encoding/nn/encoding.py -> build/lib/encoding/nn
# copying encoding/nn/customize.py -> build/lib/encoding/nn
# copying encoding/nn/comm.py -> build/lib/encoding/nn
# copying encoding/nn/syncbn.py -> build/lib/encoding/nn
# creating build/lib/encoding/lib
# copying encoding/lib/__init__.py -> build/lib/encoding/lib
# creating build/lib/encoding/dilated
# copying encoding/dilated/__init__.py -> build/lib/encoding/dilated
# copying encoding/dilated/resnet.py -> build/lib/encoding/dilated
# creating build/lib/encoding/datasets
# copying encoding/datasets/__init__.py -> build/lib/encoding/datasets
# copying encoding/datasets/pascal_aug.py -> build/lib/encoding/datasets
# copying encoding/datasets/pascal_voc.py -> build/lib/encoding/datasets
# copying encoding/datasets/base.py -> build/lib/encoding/datasets
# copying encoding/datasets/ade20k.py -> build/lib/encoding/datasets
# copying encoding/datasets/pcontext.py -> build/lib/encoding/datasets
# creating build/lib/encoding/functions
# copying encoding/functions/__init__.py -> build/lib/encoding/functions
# copying encoding/functions/encoding.py -> build/lib/encoding/functions
# copying encoding/functions/syncbn.py -> build/lib/encoding/functions
# creating build/lib/encoding/utils
# copying encoding/utils/presets.py -> build/lib/encoding/utils
# copying encoding/utils/__init__.py -> build/lib/encoding/utils
# copying encoding/utils/files.py -> build/lib/encoding/utils
# copying encoding/utils/lr_scheduler.py -> build/lib/encoding/utils
# copying encoding/utils/pallete.py -> build/lib/encoding/utils
# copying encoding/utils/train_helper.py -> build/lib/encoding/utils
# copying encoding/utils/metrics.py -> build/lib/encoding/utils
# creating build/lib/encoding/models
# copying encoding/models/encnet.py -> build/lib/encoding/models
# copying encoding/models/__init__.py -> build/lib/encoding/models
# copying encoding/models/model_store.py -> build/lib/encoding/models
# copying encoding/models/model_zoo.py -> build/lib/encoding/models
# copying encoding/models/fcn.py -> build/lib/encoding/models
# copying encoding/models/base.py -> build/lib/encoding/models
# creating build/lib/encoding/lib/cpu
# copying encoding/lib/cpu/__init__.py -> build/lib/encoding/lib/cpu
# copying encoding/lib/cpu/setup.py -> build/lib/encoding/lib/cpu
# creating build/lib/encoding/lib/gpu
# copying encoding/lib/gpu/__init__.py -> build/lib/encoding/lib/gpu
# copying encoding/lib/gpu/setup.py -> build/lib/encoding/lib/gpu
# copying encoding/lib/cpu/roi_align_cpu.cpp -> build/lib/encoding/lib/cpu
# copying encoding/lib/cpu/roi_align.cpp -> build/lib/encoding/lib/cpu
# copying encoding/lib/gpu/common.h -> build/lib/encoding/lib/gpu
# copying encoding/lib/gpu/operator.h -> build/lib/encoding/lib/gpu
# copying encoding/lib/gpu/device_tensor.h -> build/lib/encoding/lib/gpu
# copying encoding/lib/gpu/operator.cpp -> build/lib/encoding/lib/gpu
# copying encoding/lib/gpu/roi_align_kernel.cu -> build/lib/encoding/lib/gpu
# copying encoding/lib/gpu/encoding_kernel.cu -> build/lib/encoding/lib/gpu
# copying encoding/lib/gpu/syncbn_kernel.cu -> build/lib/encoding/lib/gpu
# running install_lib
# creating /usr/local/lib/python3.6/dist-packages/encoding
# copying build/lib/encoding/parallel.py -> /usr/local/lib/python3.6/dist-packages/encoding
# copying build/lib/encoding/__init__.py -> /usr/local/lib/python3.6/dist-packages/encoding
# creating /usr/local/lib/python3.6/dist-packages/encoding/nn
# copying build/lib/encoding/nn/__init__.py -> /usr/local/lib/python3.6/dist-packages/encoding/nn
# copying build/lib/encoding/nn/encoding.py -> /usr/local/lib/python3.6/dist-packages/encoding/nn
# copying build/lib/encoding/nn/customize.py -> /usr/local/lib/python3.6/dist-packages/encoding/nn
# copying build/lib/encoding/nn/comm.py -> /usr/local/lib/python3.6/dist-packages/encoding/nn
# copying build/lib/encoding/nn/syncbn.py -> /usr/local/lib/python3.6/dist-packages/encoding/nn
# creating /usr/local/lib/python3.6/dist-packages/encoding/lib
# copying build/lib/encoding/lib/__init__.py -> /usr/local/lib/python3.6/dist-packages/encoding/lib
# creating /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu
# copying build/lib/encoding/lib/cpu/__init__.py -> /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu
# copying build/lib/encoding/lib/cpu/roi_align_cpu.cpp -> /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu
# copying build/lib/encoding/lib/cpu/roi_align.cpp -> /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu
# copying build/lib/encoding/lib/cpu/setup.py -> /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu
# creating /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu
# copying build/lib/encoding/lib/gpu/operator.cpp -> /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu
# copying build/lib/encoding/lib/gpu/__init__.py -> /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu
# copying build/lib/encoding/lib/gpu/roi_align_kernel.cu -> /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu
# copying build/lib/encoding/lib/gpu/common.h -> /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu
# copying build/lib/encoding/lib/gpu/operator.h -> /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu
# copying build/lib/encoding/lib/gpu/encoding_kernel.cu -> /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu
# copying build/lib/encoding/lib/gpu/syncbn_kernel.cu -> /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu
# copying build/lib/encoding/lib/gpu/device_tensor.h -> /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu
# copying build/lib/encoding/lib/gpu/setup.py -> /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu
# copying build/lib/encoding/version.py -> /usr/local/lib/python3.6/dist-packages/encoding
# creating /usr/local/lib/python3.6/dist-packages/encoding/dilated
# copying build/lib/encoding/dilated/__init__.py -> /usr/local/lib/python3.6/dist-packages/encoding/dilated
# copying build/lib/encoding/dilated/resnet.py -> /usr/local/lib/python3.6/dist-packages/encoding/dilated
# creating /usr/local/lib/python3.6/dist-packages/encoding/datasets
# copying build/lib/encoding/datasets/__init__.py -> /usr/local/lib/python3.6/dist-packages/encoding/datasets
# copying build/lib/encoding/datasets/pascal_aug.py -> /usr/local/lib/python3.6/dist-packages/encoding/datasets
# copying build/lib/encoding/datasets/pascal_voc.py -> /usr/local/lib/python3.6/dist-packages/encoding/datasets
# copying build/lib/encoding/datasets/base.py -> /usr/local/lib/python3.6/dist-packages/encoding/datasets
# copying build/lib/encoding/datasets/ade20k.py -> /usr/local/lib/python3.6/dist-packages/encoding/datasets
# copying build/lib/encoding/datasets/pcontext.py -> /usr/local/lib/python3.6/dist-packages/encoding/datasets
# creating /usr/local/lib/python3.6/dist-packages/encoding/functions
# copying build/lib/encoding/functions/__init__.py -> /usr/local/lib/python3.6/dist-packages/encoding/functions
# copying build/lib/encoding/functions/encoding.py -> /usr/local/lib/python3.6/dist-packages/encoding/functions
# copying build/lib/encoding/functions/syncbn.py -> /usr/local/lib/python3.6/dist-packages/encoding/functions
# creating /usr/local/lib/python3.6/dist-packages/encoding/utils
# copying build/lib/encoding/utils/presets.py -> /usr/local/lib/python3.6/dist-packages/encoding/utils
# copying build/lib/encoding/utils/__init__.py -> /usr/local/lib/python3.6/dist-packages/encoding/utils
# copying build/lib/encoding/utils/files.py -> /usr/local/lib/python3.6/dist-packages/encoding/utils
# copying build/lib/encoding/utils/lr_scheduler.py -> /usr/local/lib/python3.6/dist-packages/encoding/utils
# copying build/lib/encoding/utils/pallete.py -> /usr/local/lib/python3.6/dist-packages/encoding/utils
# copying build/lib/encoding/utils/train_helper.py -> /usr/local/lib/python3.6/dist-packages/encoding/utils
# copying build/lib/encoding/utils/metrics.py -> /usr/local/lib/python3.6/dist-packages/encoding/utils
# creating /usr/local/lib/python3.6/dist-packages/encoding/models
# copying build/lib/encoding/models/encnet.py -> /usr/local/lib/python3.6/dist-packages/encoding/models
# copying build/lib/encoding/models/__init__.py -> /usr/local/lib/python3.6/dist-packages/encoding/models
# copying build/lib/encoding/models/model_store.py -> /usr/local/lib/python3.6/dist-packages/encoding/models
# copying build/lib/encoding/models/model_zoo.py -> /usr/local/lib/python3.6/dist-packages/encoding/models
# copying build/lib/encoding/models/fcn.py -> /usr/local/lib/python3.6/dist-packages/encoding/models
# copying build/lib/encoding/models/base.py -> /usr/local/lib/python3.6/dist-packages/encoding/models
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/parallel.py to parallel.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/nn/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/nn/encoding.py to encoding.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/nn/customize.py to customize.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/nn/comm.py to comm.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/nn/syncbn.py to syncbn.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/lib/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/setup.py to setup.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/lib/gpu/setup.py to setup.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/version.py to version.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/dilated/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/dilated/resnet.py to resnet.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/datasets/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/datasets/pascal_aug.py to pascal_aug.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/datasets/pascal_voc.py to pascal_voc.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/datasets/base.py to base.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/datasets/ade20k.py to ade20k.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/datasets/pcontext.py to pcontext.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/functions/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/functions/encoding.py to encoding.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/functions/syncbn.py to syncbn.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/utils/presets.py to presets.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/utils/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/utils/files.py to files.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/utils/lr_scheduler.py to lr_scheduler.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/utils/pallete.py to pallete.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/utils/train_helper.py to train_helper.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/utils/metrics.py to metrics.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/models/encnet.py to encnet.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/models/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/models/model_store.py to model_store.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/models/model_zoo.py to model_zoo.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/models/fcn.py to fcn.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/encoding/models/base.py to base.cpython-36.pyc
# running install_egg_info
# running egg_info
# creating encoding.egg-info
# writing encoding.egg-info/PKG-INFO
# writing dependency_links to encoding.egg-info/dependency_links.txt
# writing requirements to encoding.egg-info/requires.txt
# writing top-level names to encoding.egg-info/top_level.txt
# writing manifest file 'encoding.egg-info/SOURCES.txt'
# reading manifest file 'encoding.egg-info/SOURCES.txt'
# writing manifest file 'encoding.egg-info/SOURCES.txt'
# Copying encoding.egg-info to /usr/local/lib/python3.6/dist-packages/encoding-0.4.2+9bc7053-py3.6.egg-info
# running install_scripts

# %%
cd ../LightNet/scripts/
# Out:
# /content/LightNet/scripts

# %%
import os
os.environ['PYTHONPATH'] += ':/content/LightNet/'

# %%
# !apt-get install ninja-build
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   ninja-build
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 93.0 kB of archives.
# After this operation, 295 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/universe amd64 ninja-build amd64 1.7.2-3 [93.0 kB]
# Fetched 93.0 kB in 0s (1,048 kB/s)
# Selecting previously unselected package ninja-build.
# (Reading database ... 86704 files and directories currently installed.)
# Preparing to unpack .../ninja-build_1.7.2-3_amd64.deb ...
# Unpacking ninja-build (1.7.2-3) ...
# Processing triggers for man-db (2.7.6.1-2) ...
# Setting up ninja-build (1.7.2-3) ...

# %%
# !python3 deploy_model.py
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/cpp_extension.py", line 576, in _build_extension_module
#     ['ninja', '-v'], stderr=subprocess.STDOUT, cwd=build_directory)
#   File "/usr/lib/python3.6/subprocess.py", line 336, in check_output
#     **kwargs).stdout
#   File "/usr/lib/python3.6/subprocess.py", line 418, in run
#     output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['ninja', '-v']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "deploy_model.py", line 12, in <module>
#     from models.rfmobilenetv2plus import RFMobileNetV2Plus
#   File "/content/LightNet/models/rfmobilenetv2plus.py", line 6, in <module>
#     from modules import SCSEBlock, InPlaceABN, InPlaceABNWrapper, RFBlock
#   File "/content/LightNet/modules/__init__.py", line 4, in <module>
#     from . context_encode import ContextEncodeInplaceABN, ContextEncodeDropInplaceABN
#   File "/content/LightNet/modules/context_encode.py", line 4, in <module>
#     import encoding
#   File "/usr/local/lib/python3.6/dist-packages/encoding/__init__.py", line 13, in <module>
#     from . import nn, functions, dilated, parallel, utils, models, datasets
#   File "/usr/local/lib/python3.6/dist-packages/encoding/nn/__init__.py", line 12, in <module>
#     from .encoding import *
#   File "/usr/local/lib/python3.6/dist-packages/encoding/nn/encoding.py", line 18, in <module>
#     from ..functions import scaledL2, aggregate
#   File "/usr/local/lib/python3.6/dist-packages/encoding/functions/__init__.py", line 2, in <module>
#     from .encoding import *
#   File "/usr/local/lib/python3.6/dist-packages/encoding/functions/encoding.py", line 13, in <module>
#     from .. import lib
#   File "/usr/local/lib/python3.6/dist-packages/encoding/lib/__init__.py", line 12, in <module>
#     ], build_directory=cpu_path, verbose=False)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/cpp_extension.py", line 501, in load
#     _build_extension_module(name, build_directory)
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/cpp_extension.py", line 582, in _build_extension_module
#     name, error.output.decode()))
# RuntimeError: Error building extension 'enclib_cpu': [1/3] c++ -MMD -MF roi_align_cpu.o.d -DTORCH_EXTENSION_NAME=enclib_cpu -I/usr/local/lib/python3.6/dist-packages/torch/lib/include -I/usr/local/lib/python3.6/dist-packages/torch/lib/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/lib/include/THC -I/usr/include/python3.6m -fPIC -std=c++11 -c /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp -o roi_align_cpu.o
# FAILED: roi_align_cpu.o
# c++ -MMD -MF roi_align_cpu.o.d -DTORCH_EXTENSION_NAME=enclib_cpu -I/usr/local/lib/python3.6/dist-packages/torch/lib/include -I/usr/local/lib/python3.6/dist-packages/torch/lib/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/lib/include/THC -I/usr/include/python3.6m -fPIC -std=c++11 -c /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp -o roi_align_cpu.o
# In file included from /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/ArrayRef.h:18:0,
#                  from /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/ScalarType.h:5,
#                  from /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Scalar.h:11,
#                  from /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/ATen.h:6,
#                  from /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:1:
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp: In function ‘at::Tensor ROIAlignForwardCPU(const at::Tensor&, const at::Tensor&, int64_t, int64_t, double, int64_t)’:
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:388:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(input.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:388:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(input.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:389:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:389:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:390:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(input.ndimension() == 4);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:390:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(input.ndimension() == 4);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:391:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.ndimension() == 2);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:391:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.ndimension() == 2);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:392:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.size(1) == 5);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:392:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.size(1) == 5);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:404:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(roi_cols == 4 || roi_cols == 5);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:404:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(roi_cols == 4 || roi_cols == 5);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:409:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(input.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:409:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(input.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:410:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:410:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp: In function ‘at::Tensor ROIAlignBackwardCPU(const at::Tensor&, const at::Tensor&, int64_t, int64_t, int64_t, int64_t, int64_t, int64_t, double, int64_t)’:
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:444:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:444:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:445:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.ndimension() == 2);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:445:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.ndimension() == 2);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:446:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.size(1) == 5);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:446:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.size(1) == 5);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:451:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(roi_cols == 4 || roi_cols == 5);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:451:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(roi_cols == 4 || roi_cols == 5);
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:18: error: expected primary-expression before ‘(’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                   ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:456:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.is_contiguous());
#    ^~~~~~~~~
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:281:62: error: expected primary-expression before ‘)’ token
#    throw at::Error({__func__, __FILE__, __LINE__}, __VA_ARGS__)
#                                                               ^
# /usr/local/lib/python3.6/dist-packages/torch/lib/include/ATen/Error.h:285:5: note: in expansion of macro ‘AT_ERROR’
#      AT_ERROR(__VA_ARGS__);   \
#      ^~~~~~~~
# /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align_cpu.cpp:456:3: note: in expansion of macro ‘AT_ASSERT’
#    AT_ASSERT(bottom_rois.is_contiguous());
#    ^~~~~~~~~
# [2/3] c++ -MMD -MF roi_align.o.d -DTORCH_EXTENSION_NAME=enclib_cpu -I/usr/local/lib/python3.6/dist-packages/torch/lib/include -I/usr/local/lib/python3.6/dist-packages/torch/lib/include/TH -I/usr/local/lib/python3.6/dist-packages/torch/lib/include/THC -I/usr/include/python3.6m -fPIC -std=c++11 -c /usr/local/lib/python3.6/dist-packages/encoding/lib/cpu/roi_align.cpp -o roi_align.o
# ninja: build stopped: subcommand failed.

# %%
cd /content/LightNet/scripts/
# Out:
# /content/LightNet/scripts

# %%
#!kill -9 -1
